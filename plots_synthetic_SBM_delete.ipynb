# %%
import numpy as np
import pathpy as pp

def generate_bipartite_block_probs(dict_p_stud_to_task):
    n_groups_from_dict_values = set(len(v) for v in dict_p_stud_to_task.values())
    assert len(n_groups_from_dict_values)==1, "Input dict_p_stud_to_task implies varying number of groups"
    n_groups= list(n_groups_from_dict_values)[0]
    assert n_groups==len(dict_p_stud_to_task), "not enough keys"

    bip_block_probs = np.zeros((2*n_groups, 2*n_groups))
    # Fill in the probabilities within and between groups
    # Only filling probs of students to interact with tasks. 
    # Since the interactions are symmetric, the information on tasks interacting with studetns is redundant and can be obtained by summing with the transpose (see below )
    #
    # even indexes for students
    for row in range(0,2*n_groups,2):
        # odd indexes are for tasks
        for col in range(1,2*n_groups,2):
            stud_ix = row//2
            task_ix = int(col/2)
            bip_block_probs[row,col] = dict_p_stud_to_task[stud_ix][task_ix]
    return bip_block_probs + bip_block_probs.T



def sample_dcsbm(num_nodes, B, expected_degrees):
    """
    Samples a network from a degree-corrected stochastic block model
    """
    # assert False, "check that num blcks an block matrix agree"
    assert B.shape[0] == B.shape[1], "B should be square"
    num_blocks = B.shape[0]
    m = np.random.choice(num_blocks, size=num_nodes)

    # generate edges
    edge_list = []
    for i in range(num_nodes):
        for j in range(i+1, num_nodes):
            p_edge = B[m[i], m[j]]*expected_degrees[i]*expected_degrees[j]/(sum(expected_degrees))
            p_edge = min(p_edge, 1)
            assert p_edge <= 1, f"Edge probability larger than 1: {p_edge}"
            if np.random.rand() < p_edge:
                edge_list.append((i, j))

    # Create a graph and add nodes
    # network = pp.Network()
    # for u,v in edge_list:
    #     network.add_edge(u,v)
    
    # return network
    return edge_list, m

# num_nodes = 500
# # dictionary with stud index-topic as key, and list of probabiliy of interacting with task of other index-topics
# dict_p_stud_to_task = {}
# dict_p_stud_to_task[0] = [1,0,0]#,.00005]
# dict_p_stud_to_task[1] = [0,1,0]#,.001]
# dict_p_stud_to_task[2] = [0,0,1]
# bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
# # print(bip_block_probs)


# theta = np.random.randint(1,num_nodes//3,num_nodes) #np.random.uniform(low=1, high=1, size=num_nodes)  # Random 
# # theta = [int(np.random.exponential(20)) for _ in range(num_nodes)]# np.random.randint(1,100,num_nodes) #np.random.uniform(low=1, high=1, size=num_nodes)  # Random 
# edges,labels = sample_dcsbm(num_nodes, bip_block_probs, theta)

# %%
# from collections import Counter
# Counter(labels)

# %%
import torch
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from manage_experiments import *

from utils import generate_multidimensional_data_object_synthetic_geometric

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import json

# %%
# student_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==0]
# student_reindexed = {j:i for i,j in enumerate(student_indices)}
# task_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==1]
# task_reindexed = {j:i for i,j in enumerate(task_indices)}
# n_students = len(student_indices)
# n_tasks = len(task_indices)

# edge_reordered_reindexed = []
# for edge in edges:
#     if edge[0] in student_indices:
#         e = (student_reindexed[edge[0]], task_reindexed[edge[1]])
#     else:
#         e = (student_reindexed[edge[1]], task_reindexed[edge[0]])
#     edge_reordered_reindexed.append(e)

# # mapping groups to new indexing and node type separation
# student_groups = np.zeros(n_students,dtype=int)
# tasks_groups = np.zeros(n_tasks, dtype=int)

# for old_ix, new_ix in student_reindexed.items():
#     student_groups[new_ix] = labels[old_ix]

# for old_ix, new_ix in task_reindexed.items():
#     tasks_groups[new_ix] = labels[old_ix]

# # Maiking students interact with tasks according to generated topology
# p_pass_in = .9
# p_pass_out = .1
# y = []
# for s_ix, t_ix in edge_reordered_reindexed:
#     if student_groups[s_ix] == tasks_groups[t_ix]:
#         p = p_pass_in
#     else:
#         p = p_pass_out
#     y.append(np.random.binomial(1,p))

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def logarithm_base(x, base):
    return np.log(x)/np.log(base)

# %%
import torch_geometric.transforms as T

def create_data_object_SBM(edges, labels, bip_block_p_pass_probs, theta, degree_p_pass_correction=True):

    student_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==0]
    student_reindexed = {j:i for i,j in enumerate(student_indices)}
    task_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==1]
    task_reindexed = {j:i for i,j in enumerate(task_indices)}
    n_students = len(student_indices)
    n_tasks = len(task_indices)

    edge_reordered_reindexed = []
    for edge in edges:
        if edge[0] in student_indices:
            e = (student_reindexed[edge[0]], task_reindexed[edge[1]])
        else:
            e = (student_reindexed[edge[1]], task_reindexed[edge[0]])
        edge_reordered_reindexed.append(e)

    # mapping groups to new indexing and node type separation
    student_groups = np.zeros(n_students,dtype=int)
    tasks_groups = np.zeros(n_tasks, dtype=int)

    for old_ix, new_ix in student_reindexed.items():
        student_groups[new_ix] = labels[old_ix]

    for old_ix, new_ix in task_reindexed.items():
        tasks_groups[new_ix] = labels[old_ix]


    # Maiking students interact with tasks according to generated topology
    # p_pass_in = .9
    # p_pass_out = .1
    y = []
    theta_m = max(theta)
    # tau = .0
    # eta = .99
    # s = - np.log((1 + eta) / eta) / theta_m
    # print(s)
    for s_ix, t_ix in edge_reordered_reindexed:
        # if student_groups[s_ix] == tasks_groups[t_ix]:
        #     p = p_pass_in
        # else:
        #     p = p_pass_out
        p_pass = bip_block_p_pass_probs[student_groups[s_ix], tasks_groups[t_ix]]
        # if degree_p_pass_correction:
        #     # correction = logarithm_base(theta[s_ix], base)/logarithm_base(theta_m, base)#tau + (1 - tau)*sigmoid(s * theta[s_ix])
        #     p_pass = p_pass * correction
        y.append(np.random.binomial(1, p_pass))
    

    data  = HeteroData()

    # Save node indices
    data['student'].node_id = torch.arange(n_students)
    data['item'].node_id = torch.arange(n_tasks)


    # Add the node features
    data['student'].x= torch.eye(n_students)
    data['item'].x = torch.eye(n_tasks)

    # Add the edge indices
    data['student', 'responds', 'item'].edge_index = torch.from_numpy(np.array(edge_reordered_reindexed).T).to(torch.long)

    #add the edge attrs
    data['student', 'responds', 'item'].edge_attr = torch.tensor([1]*len(y)).to(torch.float).reshape(-1,1)

    # Add the edge label
    data['student', 'responds', 'item'].y = torch.from_numpy(np.array(y)).to(torch.long)

    # We use T.ToUndirected() to add the reverse edges from subject to students 
    # in order to let GNN pass messages in both ways
    data = T.ToUndirected()(data)
    del data['item', 'rev_responds', 'student'].edge_attr  # Remove 'reverse' label.
    del data['item', 'rev_responds', 'student'].y  # Remove 'reverse' label.
    return data


def generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs, degree_p_pass_correction=False):
    edges, labels = sample_dcsbm(num_nodes, bip_block_probs, theta) #generate_observations_tree_of_topics(n, n_students, n_tasks, tree_depth,branching_factor,p_ER,skill_mismatch_penalty)
    data = create_data_object_SBM(edges, labels, bip_block_p_pass_probs, theta, degree_p_pass_correction)
    # print("network density",data.num_edges/(2*n_students*n_tasks))
    return data


# data_object = generate_data_object_SBM(num_nodes, bip_block_probs, theta)
# data_object

# %%
# Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


def line_plot_with_std(list_scores, parameters, fname):

    # Convert the list of lists to a Pandas DataFrame
    df = pd.DataFrame(list_scores)

    # Calculate the mean and standard deviation of each row
    mean = df.mean(axis=1)
    std = df.std(axis=1)

    # Create a figure and an axis
    fig, ax = plt.subplots()

    # Plot the mean line
    ax.plot(mean, color='blue', label='Mean')

    # Plot the shaded region around the mean line
    ax.fill_between(df.index, mean-std, mean+std, color='lightblue', alpha=0.5, label='Standard deviation')

    # Add some labels and a legend
    ax.set_xlabel('Index')
    ax.set_ylabel('Value')
    # ax.legend()

    # change x-ticks to start from 
    n_tasks_per_student_list = list(range(
        parameters['min_n_tasks_per_student'],
        parameters['max_n_tasks_per_student'],
        parameters['step_n_tasks_per_student']))
    ax.set_xticks(range(len(n_tasks_per_student_list)), n_tasks_per_student_list, rotation=45)

    # Show and save the plot
    plt.grid()
    plt.xlabel('Number of tasks per student')
    plt.ylabel('Balanced Accuracy')
    fnameplot = fname.replace('results', 'pdf')
    plt.savefig(fnameplot)
    # plt.show()

# %%
def visualise_confusion_matrix(json_content, fname):
    fig, ax = plt.subplots(ncols = 1, figsize=(8,6))
    
    plt.imshow(json_content["Confusion_2_test"], interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()

    classes = [0, 1]
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    part1, part2 = fname.split('.')
    part1 = part1 + '_consfusion_matrix'
    fname = '.'.join([part1, part2])
    fnameplot = fname.replace('results', 'pdf')
    plt.savefig(fnameplot)

# %%
from IPython.utils import io
import matplotlib.pyplot as plt

import string
def create_filename_results(parameters,fold):
    file_name = ' '.join([f"{str(key)}-{str(value)}" for key, value in parameters.items() if key not in ['bip_block_probs','theta','bip_block_p_pass_probs', 'degree_p_pass_correction', 'base']])
    file_name += ''.join(random.choice(string.ascii_letters + string.digits) for _ in range(4))
    file_name.replace(".","")
    file_name+=".results"
    return os.path.join(fold, file_name)


#n_students_per_task_list = [2**i for i in n_students_per_task_list]

import json
def synthetic_density_effect_runs(data, parameters,parameters_density, folder = 'reporting_results'):
    parameters = {**parameters, **parameters_density}
    scores = []
    list_scores = []
    for _ in range(parameters["n_runs"]):
        with io.capture_output() as captured:
            
            cv_out = perform_cross_validation(data, parameters, save_embeddings=True)

            score = 0
            inner_list_scores = []
            for fold_n in range(parameters["n_splits"]):
                score += cv_out[f"Balanced Accuracy_{fold_n}_test"]
                inner_list_scores.extend([cv_out[f"Balanced Accuracy_{fold_n}_test"]])
            score = score / parameters["n_splits"]
            scores.append(score)
            list_scores.append(inner_list_scores)

    # density = data.num_edges/(2*parameters["n_students"]*parameters["n_tasks"]) 
    res_dict = dict(zip(list(range(parameters["n_runs"])),scores))
    output_dict = {
        **parameters,
        # "density":density,
        "res_dict":res_dict,
        "list_scores":dict(zip(list(range(parameters["n_runs"])),list_scores))
    }
    output_dict['bip_block_probs'] = output_dict['bip_block_probs'].tolist()
    output_dict['theta'] = output_dict['theta'].tolist()
    output_dict['bip_block_p_pass_probs'] = output_dict['bip_block_p_pass_probs'].tolist()
    fname = create_filename_results(parameters_density, folder)
    # print the types of items
    # print({i: type(output_dict[i]) for i,j in output_dict.items()})
    with open(fname,'w') as f:
        json.dump(output_dict, f, skipkeys=True)
    
    # save results
    # print(density)
    print([np.mean(s) for s in list_scores])
    # line_plot_with_std(list_scores=list_scores, parameters= parameters, fname=fname)

    # # save embeddings
    # visualise_embeddings(output_dict, fname=fname)

    # visualise_embeddings_concatenated(output_dict, data['student', 'responds', 'item'].edge_index, data['student', 'item'].y, fname = fname) # plot with indices of train-test split
    
    # # plot with indices of train-test split
    


    # visualise_confusion_matrix(cv_out, fname=fname)

# %%
parameters = {
    "hidden_dims": None,
    'model_type': None,
    "df_name": "synthetic.salamoia",
    "method": "EdgeClassifier",
    "epochs": 2000,
    "learning_rate": 0.05,
    "weight_decay": 0,
    "dropout": 0.0,
    "early_stopping": 250,
    "n_splits": 10,
    "device": "cuda:1",
    "done": False,
    "batch_size":64*4096,
    #
    }

# n_groups = 3
# # probability of connections between students and tasks
# dict_p_stud_to_task = {}
# dict_p_stud_to_task[0] = [1,1/(n_groups - 1),1/(n_groups - 1)]
# dict_p_stud_to_task[1] = [1/(n_groups - 1),1,1/(n_groups - 1)]
# dict_p_stud_to_task[2] = [1/(n_groups - 1),1/(n_groups - 1),1]
# bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
# # probability of passing a task given the student and the task
# dict_p_pass_stud_to_task = {}
# dict_p_pass_stud_to_task[0] = [.8,.1,.05]
# dict_p_pass_stud_to_task[1] = [.2,.7,.1]
# dict_p_pass_stud_to_task[2] = [.1,.3,.6]
# bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_stud_to_task)

# theta = np.random.randint(1,num_nodes//3,num_nodes)

parameters_density = {
    'n_runs': 1,
    'num_nodes':500,
    'bip_block_probs':None,
    'bip_block_p_pass_probs':None,
    'theta':None,
    'n_groups':None,
    'theta_type':None,
    'p_pass_out': None,
    'p_pass_in': None,	
    'degree_p_pass_correction': True,
}

# %%
# NB: having only the leaves might make it easier for IRT since it just creates separated bins (i.e., the leaves) and easy tasks (the ones sampled close to the root node)
#  Instead, with a GNN we want to leverage the ...ability to encode the underlying tree structure (HOW might the GNN do it, specifically?)
#  (np.random.normal(parameters_density["num_nodes"]/n_groups, std, parameters_density["num_nodes"]), "gaussian"), 
std = parameters_density["num_nodes"]/100
for correction in [False]:
    parameters_density['degree_p_pass_correction'] = correction
    for n_groups in [3,4,5]:
        parameters_density['n_groups'] = n_groups
        for theta in [ (np.random.randint(1,parameters_density["num_nodes"]//n_groups,parameters_density["num_nodes"]), "uniform"), (np.random.normal(parameters_density["num_nodes"]/n_groups, std, parameters_density["num_nodes"]), "gaussian")]:#, (np.random.exponential(100,parameters_density["num_nodes"]), "exponential")]:
            parameters_density['theta'] = theta[0]
            parameters_density['theta_type'] = theta[1]
            for mul_p_connection in [1, 1/2, 1/3, 2/3]:
                parameters_density['mul_p_connection'] = mul_p_connection
                dict_p_stud_to_task = {}
                for i in range(n_groups):
                    dict_p_stud_to_task[i] = [mul_p_connection/(n_groups-1)]*n_groups
                    dict_p_stud_to_task[i][i] = 1
                bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
                parameters_density['bip_block_probs'] = bip_block_probs
                parameters_density['p_pass_in'] = 1
                for p_pass_out in [.1, .3, .5, .7]:
                    dict_p_pass_stud_to_task = {}
                    for i in range(n_groups):
                        dict_p_pass_stud_to_task[i] = [p_pass_out]*n_groups
                        dict_p_pass_stud_to_task[i][i] = 1
                    parameters_density['p_pass_out'] = p_pass_out
                    bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_pass_stud_to_task)
                    parameters_density['bip_block_p_pass_probs'] = bip_block_p_pass_probs

                

                    parameters = {**parameters, **parameters_density}

                    for _ in range(45):
                        data = generate_data_object_SBM(
                                num_nodes= parameters["num_nodes"],
                                bip_block_probs = parameters["bip_block_probs"],
                                theta = parameters["theta"],
                                bip_block_p_pass_probs = parameters["bip_block_p_pass_probs"],
                                # base = parameters["base"],
                                degree_p_pass_correction=parameters["degree_p_pass_correction"]
                        )
                        
                        for model_type,hidden_dims in [
                            ("IRT",3),
                            ("GNN", [
                                16,
                                16,
                                8])]:
                            parameters["model_type"] = model_type
                            parameters["hidden_dims"] = hidden_dims
                            print('Model type:', model_type, 'hidden_dims:', hidden_dims, 'n_groups:', n_groups, 'theta:', theta[1], 'mul_p_connection:', mul_p_connection, 'p_pass_out:', p_pass_out)#, 'base:', base)
                            print('y counts', torch.bincount(data['student', 'responds', 'item'].y))
                            synthetic_density_effect_runs(data, parameters=parameters,
                                                        parameters_density=parameters_density,
                                                        )
# Out:
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2953, 3628])
# [0.8941843906240715]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2953, 3628])
# [0.9123794864813126]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2959, 3636])
# [0.9169207675894254]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2959, 3636])
# [0.9175613497551751]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2969, 3572])
# [0.9109009910336809]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([2969, 3572])
# [0.9159225759548196]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([3039, 3662])
# [0.8841436925198497]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([3039, 3662])
# [0.910238969201534]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([3001, 3736])
# [0.9064300110884933]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([3001, 3736])
# [0.9139565004583163]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2388, 4418])
# [0.785324892921924]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2388, 4418])
# [0.789563623755537]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2385, 4338])
# [0.7686632073275658]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2385, 4338])
# [0.7976279528955024]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2299, 4259])
# [0.7791498613015799]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2299, 4259])
# [0.8031123427593018]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2322, 4202])
# [0.7479571685233275]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2322, 4202])
# [0.8161714622573001]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2390, 4262])
# [0.7897588581658732]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([2390, 4262])
# [0.7983038675697494]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1659, 5065])
# [0.6477199964048083]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1659, 5065])
# [0.6939952245512705]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1719, 4947])
# [0.6229307607076654]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1719, 4947])
# [0.6923898638650322]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1702, 5025])
# [0.6432542930300269]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1702, 5025])
# [0.6318801761599019]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1718, 4866])
# [0.6395831799791646]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1718, 4866])
# [0.6659796453182667]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1707, 4971])
# [0.6119471197294757]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1707, 4971])
# [0.6724746944752263]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1002, 5566])
# [0.5335104214769434]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1002, 5566])
# [0.5417924161676929]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1010, 5587])
# [0.5087375536763503]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1010, 5587])
# [0.5327681365893012]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1021, 5734])
# [0.5290764588409018]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1021, 5734])
# [0.5573754682654343]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 997, 5623])
# [0.5216027915293621]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 997, 5623])
# [0.5285981241555436]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1013, 5467])
# [0.5148821913048137]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1013, 5467])
# [0.5451854546701487]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1434, 3369])
# [0.8595279402481826]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1434, 3369])
# [0.8926351654685314]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1534, 3490])
# [0.8699792817879493]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1534, 3490])
# [0.880960279434604]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1475, 3581])
# [0.875394572435877]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1475, 3581])
# [0.8750832127598225]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1516, 3482])
# [0.8766326070343646]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1516, 3482])
# [0.8946404093489096]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1404, 3496])
# [0.8627876925985005]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([1404, 3496])
# [0.8685851137710214]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1127, 3827])
# [0.7431153306958379]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1127, 3827])
# [0.8032439392948942]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1179, 3829])
# [0.7611144097162998]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1179, 3829])
# [0.8016576043994534]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1148, 3885])
# [0.7434095728218831]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1148, 3885])
# [0.796384393152666]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1147, 3849])
# [0.7419639001859444]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1147, 3849])
# [0.7920647005551509]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1185, 3724])
# [0.7257611188420876]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([1185, 3724])
# [0.7907908655853121]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 788, 4183])
# [0.5937130056801898]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 788, 4183])
# [0.6347963285149861]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 807, 4248])
# [0.5885989168419685]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 807, 4248])
# [0.6699631903727772]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 845, 4093])
# [0.653562518904316]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 845, 4093])
# [0.6599290540776082]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 810, 4184])
# [0.5772363751062556]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 810, 4184])
# [0.6523108168809189]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 830, 4147])
# [0.6023915373955788]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 830, 4147])
# [0.6664334316737879]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 518, 4493])
# [0.500698684374562]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 518, 4493])
# [0.5493401841503947]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 486, 4519])
# [0.5510169163762363]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 486, 4519])
# [0.5592450597543579]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 524, 4630])
# [0.5568426872282666]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 524, 4630])
# [0.5385775090158986]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 483, 4331])
# [0.4986927784717194]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 483, 4331])
# [0.5428188480109357]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 512, 4453])
# [0.5251154447510331]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 512, 4453])
# [0.5281682354802274]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1010, 3345])
# [0.8383459771390495]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1010, 3345])
# [0.8602964387784013]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1016, 3495])
# [0.8462774424482701]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1016, 3495])
# [0.8133798602413794]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1008, 3468])
# [0.7921272093889139]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1008, 3468])
# [0.8484933393201475]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1005, 3379])
# [0.8383199432061279]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([1005, 3379])
# [0.8219748935004585]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 999, 3440])
# [0.8478986423326376]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 999, 3440])
# [0.8042235027311243]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 756, 3609])
# [0.6798283660224876]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 756, 3609])
# [0.7415010244983351]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 785, 3733])
# [0.68365208336315]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 785, 3733])
# [0.743055693453901]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 789, 3677])
# [0.6790141955160621]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 789, 3677])
# [0.7259052553605806]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 767, 3704])
# [0.6786088779918867]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 767, 3704])
# [0.7152348645002083]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 810, 3609])
# [0.7017445822860979]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 810, 3609])
# [0.7314388225464598]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 573, 3794])
# [0.5741901981459773]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 573, 3794])
# [0.6191654397588016]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 571, 3847])
# [0.5911304237865761]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 571, 3847])
# [0.6631029529892968]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 567, 3882])
# [0.5705979504441541]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 567, 3882])
# [0.5828987423475344]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 568, 3849])
# [0.5941345645518528]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 568, 3849])
# [0.6011361385824379]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 568, 3911])
# [0.5787849761675891]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 568, 3911])
# [0.641145251258941]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 342, 4118])
# [0.4745610144977016]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 342, 4118])
# [0.5657455169466699]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 317, 3976])
# [0.5381600882381422]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 317, 3976])
# [0.5094711056480592]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 321, 4086])
# [0.5106057103270583]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 321, 4086])
# [0.491088030658345]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 279, 4195])
# [0.48393001148743453]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 279, 4195])
# [0.5139790426494022]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 343, 4195])
# [0.5145866046270153]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 343, 4195])
# [0.5072782103897122]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1936, 3585])
# [0.8958620454809406]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1936, 3585])
# [0.8974995233619996]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1960, 3548])
# [0.9059793780229622]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1960, 3548])
# [0.9031581179309545]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1997, 3502])
# [0.9085562935910134]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1997, 3502])
# [0.9059999502292261]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1996, 3554])
# [0.9015204159273654]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1996, 3554])
# [0.9153336589373564]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([2031, 3522])
# [0.8937792655662499]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([2031, 3522])
# [0.915508253587288]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1561, 3937])
# [0.7551795586904967]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1561, 3937])
# [0.7990152683630953]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1574, 3942])
# [0.7716619475252361]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1574, 3942])
# [0.7922844423618287]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1498, 4030])
# [0.7722460253250623]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1498, 4030])
# [0.7890061293771052]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1452, 4017])
# [0.7649709554742404]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1452, 4017])
# [0.7805950030507217]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1561, 4002])
# [0.7681114077769424]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1561, 4002])
# [0.7810205039555992]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1119, 4479])
# [0.6319187521042443]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1119, 4479])
# [0.6657366310510586]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1138, 4374])
# [0.6434308326147221]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1138, 4374])
# [0.6484652618254623]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1154, 4364])
# [0.67434714560994]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1154, 4364])
# [0.6981847607690211]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1143, 4492])
# [0.6147658897218202]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1143, 4492])
# [0.6793674314898659]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1141, 4499])
# [0.6444666738402508]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([1141, 4499])
# [0.6738756014225717]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 638, 4838])
# [0.5116884884063764]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 638, 4838])
# [0.5639113070769184]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 661, 4852])
# [0.5384798277224989]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 661, 4852])
# [0.5852893954839601]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 668, 4864])
# [0.5274525191941243]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 668, 4864])
# [0.5233482828719503]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 645, 4819])
# [0.49577874913022874]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 645, 4819])
# [0.5129649317758609]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 719, 4880])
# [0.5319396823931354]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: uniform mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 719, 4880])
# [0.554180386644948]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6307, 7544])
# [0.9462947768650078]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6307, 7544])
# [0.9517316585612591]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6215, 7691])
# [0.9447621057705667]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6215, 7691])
# [0.9510853141090774]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6233, 7753])
# [0.9475993271553044]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6233, 7753])
# [0.949749354163554]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6211, 7564])
# [0.9463595970723153]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6211, 7564])
# [0.9494041657243739]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6216, 7724])
# [0.9433593209560595]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.1
# y counts tensor([6216, 7724])
# [0.9449450790716153]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4995, 9262])
# [0.8210037460990932]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4995, 9262])
# [0.8715745787503331]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4842, 8806])
# [0.8431246912040026]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4842, 8806])
# [0.8748559980250212]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4849, 8907])
# [0.8483413442898715]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4849, 8907])
# [0.8724400953849589]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4959, 8884])
# [0.8532844076965322]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4959, 8884])
# [0.8718733547677173]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4854, 9053])
# [0.851623581024417]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.3
# y counts tensor([4854, 9053])
# [0.8675849830567929]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3389, 10378])
# [0.7512643704887085]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3389, 10378])
# [0.804306039719824]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3514, 10304])
# [0.7646942157721457]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3514, 10304])
# [0.7985754504375155]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3492, 10422])
# [0.7350712069735488]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3492, 10422])
# [0.804220403588037]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3550, 10296])
# [0.7671385618650444]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3550, 10296])
# [0.7935634760596677]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3434, 10286])
# [0.7628656982468447]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 3434, 10286])
# [0.8024307145824157]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2174, 11835])
# [0.6687235692537578]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2174, 11835])
# [0.705655250291821]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2135, 11858])
# [0.6916874643967781]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2135, 11858])
# [0.7129393553816075]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2070, 11679])
# [0.6405982903983451]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2070, 11679])
# [0.6818747634148259]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2171, 11710])
# [0.6739470564176566]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2171, 11710])
# [0.6857458573222377]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2019, 11721])
# [0.6356403430033024]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 2019, 11721])
# [0.7025293934345023]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3048, 7278])
# [0.9453348331851025]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3048, 7278])
# [0.9458364152567571]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3088, 7257])
# [0.9516828753086897]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3088, 7257])
# [0.9429335803216281]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3213, 7446])
# [0.9560302126419284]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3213, 7446])
# [0.9453714524874972]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3088, 7207])
# [0.9428555572046253]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3088, 7207])
# [0.9423016070871695]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3123, 7228])
# [0.9521001075041967]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.1
# y counts tensor([3123, 7228])
# [0.9444668883826732]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2388, 7863])
# [0.85982830045691]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2388, 7863])
# [0.8694120790706309]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2403, 7994])
# [0.8636718245896289]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2403, 7994])
# [0.8830091869971559]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2334, 7757])
# [0.8597503441281974]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2334, 7757])
# [0.864362441909184]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2317, 8001])
# [0.8595317964349054]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2317, 8001])
# [0.8928318252166904]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2454, 7941])
# [0.8538744171195909]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.3
# y counts tensor([2454, 7941])
# [0.8611227152209043]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1752, 8664])
# [0.7709678319911406]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1752, 8664])
# [0.8083001605761762]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1766, 8518])
# [0.753851332360845]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1766, 8518])
# [0.7765248883938478]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1709, 8700])
# [0.7644143294323882]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1709, 8700])
# [0.8007829079534886]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1760, 8582])
# [0.7367790996555026]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1760, 8582])
# [0.8052619341422096]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1703, 8672])
# [0.7569073203691137]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([1703, 8672])
# [0.795197661421362]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1060, 9324])
# [0.6042000861603192]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1060, 9324])
# [0.6915848939194887]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1043, 9240])
# [0.5899518865057625]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1043, 9240])
# [0.6171266325197927]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1062, 9269])
# [0.583418342087071]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1062, 9269])
# [0.6427944902188105]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1052, 9395])
# [0.5769030524394687]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1052, 9395])
# [0.6821913782289937]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1060, 9286])
# [0.5805023904241555]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([1060, 9286])
# [0.6973688435232742]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2131, 7056])
# [0.9394072967803415]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2131, 7056])
# [0.9245649265033231]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2092, 7199])
# [0.9330181919354971]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2092, 7199])
# [0.915697446364207]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2127, 7075])
# [0.9514313311423903]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2127, 7075])
# [0.9165794939372173]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2202, 7211])
# [0.937096087762832]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2202, 7211])
# [0.9240661022200909]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2090, 7188])
# [0.938809809416016]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([2090, 7188])
# [0.9086447767630922]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1610, 7590])
# [0.8306017981167846]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1610, 7590])
# [0.8315056235470681]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1570, 7519])
# [0.8141643306955532]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1570, 7519])
# [0.833925119647079]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1611, 7496])
# [0.8415231419555008]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1611, 7496])
# [0.8476405533446021]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1613, 7592])
# [0.8048514696774486]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1613, 7592])
# [0.8336596813253143]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1557, 7594])
# [0.8307504347648493]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([1557, 7594])
# [0.8340977398376515]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1157, 8058])
# [0.6924968670399274]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1157, 8058])
# [0.7340562111293834]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1164, 7925])
# [0.7046663361004116]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1164, 7925])
# [0.7480567198553002]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1187, 8166])
# [0.7044703372176407]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1187, 8166])
# [0.7600238203215931]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1129, 8146])
# [0.6955583529035162]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1129, 8146])
# [0.7458790076864472]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1208, 7993])
# [0.7101541572306829]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([1208, 7993])
# [0.7689436552227319]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 702, 8382])
# [0.5639017362022603]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 702, 8382])
# [0.6192730049156012]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 699, 8472])
# [0.5613187762728105]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 699, 8472])
# [0.6502018500130682]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 704, 8499])
# [0.552207508471873]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 704, 8499])
# [0.6406693764403592]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 689, 8592])
# [0.5418252800947194]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 689, 8592])
# [0.6386159721621201]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 683, 8621])
# [0.5735200677757092]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 683, 8621])
# [0.6145822097799873]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4149, 7559])
# [0.9571793483674325]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4149, 7559])
# [0.959310406006562]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4206, 7416])
# [0.9538645086471872]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4206, 7416])
# [0.954362775671895]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4176, 7340])
# [0.9556889274098191]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4176, 7340])
# [0.9558248700613818]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4143, 7255])
# [0.9478027048818802]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4143, 7255])
# [0.9529320557260774]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4087, 7325])
# [0.9476129685378385]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([4087, 7325])
# [0.9488116614080091]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3254, 8326])
# [0.8495162536412701]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3254, 8326])
# [0.8802935891809647]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3211, 8200])
# [0.860561456160237]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3211, 8200])
# [0.8838207712290671]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3118, 8292])
# [0.8546275211590837]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3118, 8292])
# [0.8763496490995382]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3343, 8401])
# [0.8613369219043261]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3343, 8401])
# [0.8903127689065095]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3260, 8466])
# [0.8627526041854064]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([3260, 8466])
# [0.8963721042261638]
# Model type: IRT hidden_dims: 3 n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([2307, 9206])
# [0.7699123206751672]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 3 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# ...
# y counts tensor([ 632, 3109])
# [0.5301725510166018]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 661, 3267])
# [0.5133117761428996]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 661, 3267])
# [0.5217584118797874]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 664, 3166])
# [0.5160492020684805]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 664, 3166])
# [0.507604563536578]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 592, 3081])
# [0.5137762836735641]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.5
# y counts tensor([ 592, 3081])
# [0.5170335584068068]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 394, 3347])
# [0.5198442355958818]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 394, 3347])
# [0.5221044775884107]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 407, 3346])
# [0.4729250647813643]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 407, 3346])
# [0.507135110153381]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 399, 3327])
# [0.4825118485882657]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 399, 3327])
# [0.5048829184293089]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 340, 3396])
# [0.5146580207244023]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 340, 3396])
# [0.509223159317929]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 394, 3298])
# [0.5187590071437597]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.5 p_pass_out: 0.7
# y counts tensor([ 394, 3298])
# [0.4923789647434546]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 769, 2510])
# [0.5452580077539948]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 769, 2510])
# [0.642712695139536]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 808, 2576])
# [0.6004490041671169]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 808, 2576])
# [0.6562144612666932]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 758, 2595])
# [0.5845552358114586]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 758, 2595])
# [0.6296300693890459]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 716, 2573])
# [0.5520957267069394]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 716, 2573])
# [0.5870031848259503]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 713, 2574])
# [0.5732804640247083]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.1
# y counts tensor([ 713, 2574])
# [0.603596860518371]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 564, 2686])
# [0.47773753835886107]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 564, 2686])
# [0.5648834808353072]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 586, 2830])
# [0.5216108489931399]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 586, 2830])
# [0.5275070056350356]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 599, 2777])
# [0.5590509060575685]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 599, 2777])
# [0.552558864566432]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 558, 2758])
# [0.47951512542488495]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 558, 2758])
# [0.5206523239971925]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 619, 2706])
# [0.5273670227391312]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.3
# y counts tensor([ 619, 2706])
# [0.5448264963816083]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 428, 2915])
# [0.5257077618889421]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 428, 2915])
# [0.49992669267776196]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 424, 2879])
# [0.49377028784432736]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 424, 2879])
# [0.4843743647764761]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 441, 2911])
# [0.5081810294807]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 441, 2911])
# [0.5072087922242691]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 426, 2887])
# [0.506103377180752]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 426, 2887])
# [0.5196851455567812]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 441, 2888])
# [0.5047242071677638]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.5
# y counts tensor([ 441, 2888])
# [0.5159899074752878]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 253, 3026])
# [0.5366866586337262]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 253, 3026])
# [0.5155603401623565]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 234, 3062])
# [0.5350228531036245]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 234, 3062])
# [0.5108821154269415]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 256, 3073])
# [0.5099262423581041]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 256, 3073])
# [0.4872309362337469]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 249, 3121])
# [0.4588871240890894]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 249, 3121])
# [0.503647915298053]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 255, 3097])
# [0.5046129998536466]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.3333333333333333 p_pass_out: 0.7
# y counts tensor([ 255, 3097])
# [0.48565084427577004]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1536, 2629])
# [0.7238968512996898]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1536, 2629])
# [0.8165381359580897]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1539, 2694])
# [0.7123038924296953]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1539, 2694])
# [0.8212863827473937]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1540, 2675])
# [0.723333482079344]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1540, 2675])
# [0.802833567484784]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1504, 2755])
# [0.7228264807865366]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1504, 2755])
# [0.8182502133431371]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1477, 2672])
# [0.6893654828138731]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.1
# y counts tensor([1477, 2672])
# [0.8136692783079423]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1140, 2911])
# [0.5474973829506303]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1140, 2911])
# [0.5920647835243248]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1164, 2979])
# [0.5495073222157514]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1164, 2979])
# [0.6312818561076508]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1163, 2953])
# [0.5734614472137838]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1163, 2953])
# [0.6688512188229124]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1131, 3082])
# [0.6023253127959185]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1131, 3082])
# [0.6603618073009097]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1206, 2979])
# [0.5969867071847332]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.3
# y counts tensor([1206, 2979])
# [0.66580457175387]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 830, 3168])
# [0.5320821589400657]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 830, 3168])
# [0.5256654113535166]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 862, 3260])
# [0.5143693331304315]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 862, 3260])
# [0.5306743770963352]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 784, 3265])
# [0.5175700867383345]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 784, 3265])
# [0.5048503483167031]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 794, 3328])
# [0.5059310381207689]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 794, 3328])
# [0.5382049462156655]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 823, 3335])
# [0.508118696858257]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.5
# y counts tensor([ 823, 3335])
# [0.5177796735202758]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 518, 3607])
# [0.5428870404911783]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 518, 3607])
# [0.5047465277352273]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 490, 3783])
# [0.47222129449072714]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 490, 3783])
# [0.4950563436645233]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 487, 3660])
# [0.5211511716034929]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 487, 3660])
# [0.5261810828836969]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 550, 3579])
# [0.48777905592987436]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 550, 3579])
# [0.49979267718021186]
# Model type: IRT hidden_dims: 3 n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 515, 3626])
# [0.49992903748075745]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 5 theta: gaussian mul_p_connection: 0.6666666666666666 p_pass_out: 0.7
# y counts tensor([ 515, 3626])
# [0.5251390109044596]

# %%
import os
import pandas as pd
import json
import numpy as np

def read_json_files(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".results"):
            filepath = os.path.join(directory, filename)
            with open(filepath, 'r') as file:
                json_data = json.load(file)
                data.append(json_data)
    df = pd.DataFrame(data)
    return df

# %%
df = read_json_files('reporting_results')

# %%
# df['list_scores_latex'] = df['list_scores'].apply(lambda x: f"{np.mean([np.mean(v)*100 for v in x.values()]):.2f} ± {np.std([np.mean(v)*100 for v in x.values()]):.2f}")
df['list_scores_latex'] = df['list_scores'].apply(lambda x: f"{np.mean([v for v in x.values()])*100:.2f} ± {np.std([v for v in x.values()])*100:.2f}")

# %%
group_cols = [
    'p_pass_out', 
    # 'bip_block_p_pass_probs', 
    'theta_type', 
    'n_groups', 
    'mul_p_connection',
    'model_type',
    'degree_p_pass_correction',
    # 'base'
    ]

# %%
grouped = df.groupby(group_cols).agg({
    'list_scores': lambda x: x.apply(lambda y: np.mean([v for v in y.values()])),
    }).reset_index()

# %%
std_list = []
mean_list = []
for dict_values in df.list_scores.values:
    std_list.append(np.std(dict_values['0']))
    mean_list.append(np.mean(dict_values['0']))

df['std'] = std_list
df['mean'] = mean_list

# %%
def col_selector(df, cols, values):
    mask = np.full(len(df), True)
    for col, value in zip(cols, values):
        mask = mask & (df[col] == value)
    return mask

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_line_graph(df, xaxis_col, list_scores_col, label=""):
    # Set the style of the plot
    sns.set_style("darkgrid")
    # Set color palette
    sns.set_palette("colorblind")

    # Create the plot
    x_values = df[xaxis_col]
    y_mean = df[list_scores_col].apply(lambda x: np.mean(x))
    y_std = df[list_scores_col].apply(lambda x: np.std(x))

    # Create an error bar plot with a line marker style
    plt.errorbar(x_values, y_mean, yerr=y_std, fmt='-o', label=label, capsize=5)

    # Set the labels and title
    plt.xlabel(xaxis_col, fontsize=16)
    plt.ylabel('Mean Scores', fontsize=16)
    plt.title('Line Graph', fontsize=20)
    plt.ylim(20, 100)

    # Add a legend
    plt.legend(fontsize=14)

    # Show the plot
    # plt.show()

# %%
df_select_GNN = df[col_selector(df, ['theta_type', 'n_groups', 'mul_p_connection', 'model_type'], ['uniform', 3, 1/2, 'GNN'])]
df_select_IRT = df[col_selector(df, ['theta_type', 'n_groups', 'mul_p_connection', 'model_type'], ['uniform', 3, 1/2, 'IRT'])]

plot_line_graph(df_select_GNN, 'p_pass_out', 'mean', label='GNN')
plot_line_graph(df_select_IRT, 'p_pass_out', 'mean', label='IRT')
plt.legend()

# %%
# df_select_GNN = grouped[col_selector(grouped, ['theta_type', 'n_groups', 'mul_p_connection', 'model_type'], ['lognormal', 3, 1/2, 'GNN'])]
# df_select_IRT = grouped[col_selector(grouped, ['theta_type', 'n_groups', 'mul_p_connection', 'model_type'], ['lognormal', 3, 1/2, 'IRT'])]

# plot_line_graph(df_select_GNN, 'p_pass_out', 'list_scores', label='GNN')
# plot_line_graph(df_select_IRT, 'p_pass_out', 'list_scores', label='IRT')
# plt.legend()

# %%
grouped['Mean'] = grouped['list_scores'].apply(lambda x: round(np.mean(x),2))
grouped['Std'] = grouped['list_scores'].apply(lambda x: round(np.std(x),2))

# %%
# df_list = []
# for group, df_group in grouped.groupby(['n_groups', 'theta_type', 'mul_p_connection', 'p_pass_out']):
#     try:
#         gain = (df_group[df_group['model_type'] == 'GNN']['Mean'].values[0] - df_group[df_group['model_type'] == 'IRT']['Mean'].values[0]) / df_group[df_group['model_type'] == 'IRT']['Mean'].values[0]*100
#         std = np.sqrt((df_group[df_group['model_type'] == 'GNN']['Std'].values[0])**2 + (df_group[df_group['model_type'] == 'IRT']['Std'].values[0])**2)
#         df_list.append(pd.DataFrame({
#             'n_groups': [group[0]],
#             'theta_type': [group[1]],
#             'mul_p_connection': [group[2]],
#             'p_pass_out': [group[3]],
#             'gain': [gain],
#             'std': [std]	
#         }))
#     except:
#         continue

df_list = []
for group, df_group in df.groupby(['n_groups', 'theta_type', 'mul_p_connection', 'p_pass_out', 'degree_p_pass_correction']):
    try:
        gain = (df_group[df_group['model_type'] == 'GNN']['mean'].values[0] - df_group[df_group['model_type'] == 'IRT']['mean'].values[0]) / df_group[df_group['model_type'] == 'IRT']['mean'].values[0]*100
        std = np.sqrt((df_group[df_group['model_type'] == 'GNN']['std'].values[0])**2 + (df_group[df_group['model_type'] == 'IRT']['std'].values[0])**2)
        df_list.append(pd.DataFrame({
            'n_groups': [group[0]],
            'theta_type': [group[1]],
            'mul_p_connection': [group[2]],
            'p_pass_out': [group[3]],
            # 'base': [group[4]],
            'degree_p_pass_correction': [group[4]],
            'gain': [gain],
            'std': [std *100],
            'bottom': df_group[df_group['model_type'] == 'IRT']['mean'].values[0]*100	
        }))
    except:
        continue

# %%
new_df = pd.concat(df_list)

# %%
new_df.columns
# Out:
# Index(['n_groups', 'theta_type', 'mul_p_connection', 'p_pass_out',
#        'degree_p_pass_correction', 'gain', 'std', 'bottom'],
#       dtype='object')

# %%
mul_p_connection = 2/3


theta_types = ['gaussian', 'uniform']
n_groups = [3, 4, 5]
base = 10
degree_p_pass_correction = True

fig, axes = plt.subplots(
    len(n_groups),
    len(theta_types),
    figsize=(15, 15),
    sharey=True
    )
for theta_type in theta_types: 
    for ng in n_groups:
        col = theta_types.index(theta_type)
        row = n_groups.index(ng)
        sub_new_df = new_df[
            (new_df['theta_type'] == theta_type) & 
            (new_df['n_groups'] == ng) & 
            (new_df['mul_p_connection'] == mul_p_connection) 
            # (new_df['base'] == base) &
            # (new_df['degree_p_pass_correction'] == degree_p_pass_correction)
            ]
        
        
        # sns.barplot(data=sub_new_df, x='p_pass_out', y='gain', ax = axes[row,col])
        # axes[row,col].set_title(f" {theta_type}, {ng} groups")
        # color the bars: redu if positive gain, blue if negative
        sub_new_df = sub_new_df.copy()
        sub_new_df['color'] = sub_new_df['gain'].apply(lambda x: 'blue' if x>0 else 'red')
        axes[row, col].bar(
            x=sub_new_df['p_pass_out'],
            height=sub_new_df['gain'],
            yerr=sub_new_df['std'],
            color=sub_new_df['color'].values.tolist(),
            width=0.1,
            align='center',
            bottom=sub_new_df['bottom']
            )
        axes[row,col].set_title(f" {theta_type}, {ng} groups,")# {base} base")
        axes[row,col].set_xlabel('p_pass_out')
        axes[row,col].set_ylabel('Gain (%)')
        # axes[row,col].set_ylim(-20, 20)

# theta_type = 'uniform'
# n_groups = 3

# sub_new_df = new_df[(new_df['theta_type'] == theta_type) & (new_df['n_groups'] == n_groups) & (new_df['mul_p_connection'] == mul_p_connection)]


# fig, axes = plt.subplots(1, 1, figsize=(10, 15))


# sns.barplot(data=sub_new_df, x='p_pass_out', y='gain', ax = axes)
# axes.set_title("fucl")

plt.savefig(f'plots_synthetic/Mul_p_connection_{mul_p_connection}.pdf')

# %%
df[(df['model_type'] == 'GNN') & (df['mul_p_connection'] == 2/3) & (df['p_pass_out'] == 0.1) & (df['theta_type'] == 'lognormal') & (df['n_groups'] == 3)]

# %%
df[(df['model_type'] == 'IRT') & (df['mul_p_connection'] == 2/3) & (df['p_pass_out'] == 0.1) & (df['theta_type'] == 'lognormal') & (df['n_groups'] == 3)]

# %%
new_df_gaussian = new_df[new_df['theta_type'] == 'gaussian']
new_df_lognormal = new_df[new_df['theta_type'] == 'lognormal']
new_df_uniform = new_df[new_df['theta_type'] == 'uniform']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(10, 15))

sns.barplot(x='n_groups', y='gain', data=new_df_gaussian, ax=axes[0,0])
axes[0,0].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_gaussian, ax=axes[1,0])
axes[1,0].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_gaussian, ax=axes[2,0])
axes[2,0].set_title('p_pass_out')


sns.barplot(x='n_groups', y='gain', data=new_df_uniform, ax=axes[0,1])
axes[0,1].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_uniform, ax=axes[1,1])
axes[1,1].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_uniform, ax=axes[2,1])
axes[2,1].set_title('p_pass_out')


sns.barplot(x='n_groups', y='gain', data=new_df_lognormal, ax=axes[0,2])
axes[0,2].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_lognormal, ax=axes[1,2])
axes[1,2].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_lognormal, ax=axes[2,2])
axes[2,2].set_title('p_pass_out')

plt.tight_layout()
plt.show()

# %%
n_nodes=500
mu = 20
plt.hist(np.random.lognormal(mean=np.log(mu),sigma=np.log(2),size=n_nodes), bins = 100)
plt.vlines(x=mu,ymin=0,ymax=15,colors="red")
plt.show()

# %%
def generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs):
    edges, labels = sample_dcsbm(num_nodes, bip_block_probs, theta) #generate_observations_tree_of_topics(n, n_students, n_tasks, tree_depth,branching_factor,p_ER,skill_mismatch_penalty)
    data = create_data_object_SBM(edges, labels, bip_block_p_pass_probs)
    # print("network density",data.num_edges/(2*n_students*n_tasks))
    return data

# %%
num_nodes = 500
theta = np.random.lognormal(mean=np.log(20),sigma=np.log(2),size=num_nodes)
n_groups = 3
mul_p_connection = 1/2
dict_p_stud_to_task = {}
for i in range(n_groups):
    dict_p_stud_to_task[i] = [mul_p_connection/(n_groups-1)]*n_groups
    dict_p_stud_to_task[i][i] = 1
bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)

p_pass_out = .1
dict_p_pass_stud_to_task = {}
for i in range(n_groups):
    dict_p_pass_stud_to_task[i] = [p_pass_out]*n_groups
    dict_p_pass_stud_to_task[i][i] = 1
parameters_density['p_pass_out'] = p_pass_out
bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_pass_stud_to_task)

data = generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs)

# %%
grouped.reset_index(inplace=True)

# %%
df.columns

# %%
for p_val in grouped.p_pass_out.unique():
    print(p_val,grouped[grouped.p_pass_out == p_val].n_groups.unique())

# %%
for p_val in grouped.p_pass_out.unique():
    print(grouped[grouped.p_pass_out == p_val].mul_p_connection.unique())

# %%
grouped[grouped.p_pass_out == p_val]

# %%
import numpy as np

# %%
def sigmoid(x, alpha):
    return 1/(1+np.exp(-x/alpha))

# %%
x = np.arange(-9,10)
plt.plot(x, [sigmoid(xi,0) for xi in x], label="alpha = 0")
plt.plot(x, [sigmoid(xi,1) for xi in x], label="alpha = 1")
plt.plot(x, [sigmoid(xi,2) for xi in x], label="alpha = 2")
plt.plot(x, [sigmoid(xi,3) for xi in x], label="alpha = 3")
plt.legend()

# %%
import pathpy as pp
from collections import defaultdict 
import copy
# tree
root = "*"
max_depth = 3
nodes_at_layer = defaultdict(list)
nodes_at_layer[0].append(root)
start_nodes = ["0","1"]
nodes_at_layer[1].extend(start_nodes)
for depth in range(2,max_depth+1):
    # nodes_this_layer = []
    # nodes_prev_layer = copy.deepcopy(nodes_at_layer[depth-1])
    for node in nodes_at_layer[depth-1]:
        for base_node in start_nodes:
            nodes_at_layer[depth].append(node+base_node)


nodes_at_layer

# %%
n = pp.Network(directed = True)
for depth in range(max(nodes_at_layer)):
    if depth == 0:
        for node in nodes_at_layer[1]:
            n.add_edge(root,node)
    else:
        for node_parent in nodes_at_layer[depth]:
            for node_child in nodes_at_layer[depth+1]:
                if node_child[:-1]==node_parent:
                    n.add_edge(node_parent,node_child)
print(n.ncount())
pp.visualisation.plot(n, width = 800,height = 800)

# %%
nodes = list(n.nodes)
n_items = 100
# NB: randomly sampling nodes will disproportionately give leaves, i.e., difficult items.
item_positions = np.random.choice(nodes,size=n_items)
dict_item_positions = dict(zip(range(n_items),item_positions))

# %%
def assign_skills(n, study_hours,root="*"):
    # gives skills to students
    # we start by taking one random path from root to leaf for each student
    # extensions goes in the direction of using personalized pagerank from the root node and would include: 
    #   study hours (similar to ability, encodes number of transitions taken by the students rw)
    #   restart probability tau at any node
    #   once an end node is reached, student restards from prev visited node (or root) with prob 1
    #
    # for now just enough to reach one leaf
    T = n.transition_matrix().todense().T
    root_index = n.node_to_name_map()[root]
    ix_to_node = {v:k for k,v in n.node_to_name_map().items()}
    last_node_ix = root_index
    for _ in range(study_hours):
        last_node_ix = np.random.choice(range(n.ncount()),p=T[last_node_ix,:].tolist()[0])
    return ix_to_node[last_node_ix]


n_students = 100
dict_students_abilities = {stud_id:[] for stud_id in range(n_students)}
for stud_id in dict_students_abilities:
    # append, but potentially extend cause students can get skills in different branches
    dict_students_abilities[stud_id].append(assign_skills(n,depth+1))
# dict_students_abilities

# %%
# students interact randomly with items (erdos renyi). Student pass items if they have traversed the topic/tree-node in their learning path
p_ER = .3
edges = []
labels = []
for stud_id in dict_students_abilities:
    for item_id in dict_item_positions:
        if np.random.rand()<p_ER:
            edges.append((stud_id,item_id))
            # deciding if item is passed
            # could be made more nuanced checking how much of the path to the item_topic has been traversed by the student
            item_topic = dict_item_positions[item_id] 
            student_skills = dict_students_abilities[stud_id]
            if any([item_topic==skill[:len(item_topic)] for skill in student_skills if len(skill)>=len(item_topic)]):
                labels.append(1)
            else:
                labels.append(0)

print(sum(labels)/len(labels))

# %%
# GENERATING NODE POSITIONS AND PLOTTING THEM 
# NB: ALSO SETTING RADIUS USED BELOW

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
dimension = 2
n_students = 270
n_items = 750
#
student_geom = np.random.rand(n_students,dimension)
student_ids = range(n_students)
items_geom = np.random.rand(n_items,dimension)
items_id = range(n_students, n_students+n_items)
#
radius = .1
fig,ax = plt.subplots()
ax.scatter(student_geom[:,0],student_geom[:,1], label = "student")
ax.scatter(items_geom[:,0],items_geom[:,1], label = "item")
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
circle = Circle([.5,.5], radius, fill=False, edgecolor='red')
ax.add_patch(circle)
plt.legend()

# %%
# GENERATING NODE POSITIONS AND PLOTTING THEM 
# NB: ALSO SETTING RADIUS USED BELOW

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
dimension = 2
n_students = 270
n_items = 750
#
student_geom = np.random.rand(n_students,dimension)
student_ids = range(n_students)
items_geom = np.random.rand(n_items,dimension)
items_id = range(n_students, n_students+n_items)
#
radius = .1
fig,ax = plt.subplots()
ax.scatter(student_geom[:,0],[0]*len(student_geom[:,1]), label = "student")
ax.scatter([0]*len(items_geom[:,0]),items_geom[:,1], label = "item")
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
# circle = Circle([.5,.5], radius, fill=False, edgecolor='red')
# ax.add_patch(circle)
plt.legend()

# %%
np.random.rand()

# %%
n_students = 100
n_items = 150

list_a = [np.random.randint(50)/50 for _ in range(n_students)]
list_i = [np.random.randint(50)/50 for _ in range(n_items)]

edges = []
for i in range(n_students):
    # ability student i
    a_i = list_a[i]
    for j in range(n_items):
        # difficulty item j
        d_j = list_i[j]
        # delta gives how appropriate taks diff is for student ability
        delta = abs(a_i - d_j)
        # probability of interaction prop to inverse of delta: 
        p_i_j = 1/(2+delta)**4
        assert p_i_j <= 1
        if np.random.rand()<p_i_j:
            edges.append((i,i+j))

# %%
import pathpy as pp
n = pp.Network(directed=True)
for (u,v) in edges:
    n.add_edge(u,v)
pp.visualisation.plot(n, width =800,height = 800)

# %%
# OBTAINING PROBABILITY (AND PLOTTING PATTERNS FOR ON EDGES -- POSITION TAKING AVERAGE BETWEEN NODES INVOLVED IN THE INTERACTIONS)
label_probs = []
list_edge_points = []
for i in range(n_students):
    for j in range(n_items):
        if np.linalg.norm(student_geom[i]-items_geom[j]) < radius:
            # first coordinate used as student ability 
            # second coordinate used as item difficulty
            x = student_geom[i][0]-items_geom[j][1]
            label_probs.append(1/(1+np.exp(-x)))
            list_edge_points.append((student_geom[i]+items_geom[j])/2)

list_edge_points = np.array(list_edge_points)
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
plt.scatter(list_edge_points[:,0],list_edge_points[:,1], c=label_probs)
plt.colorbar()

# %%
# # CREATING LIST OF EDGES
# # import pathpy as pp
# import numpy as np
# n = pp.Network()
# edges = []
# for i in range(n_students):
#     for j in range(n_items):
#         if np.linalg.norm(student_geom[i]-items_geom[j]) < radius:
#             edges.append((i,i+j))
#             n.add_edge(i,n_students+j)


# # COOL DRAGON-LIKE VISUALIZATION
# # pp.visualisation.plot(n, width =800,height = 800)
