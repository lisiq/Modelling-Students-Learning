# %%
import numpy as np
import pathpy as pp

def generate_bipartite_block_probs(dict_p_stud_to_task):
    n_groups_from_dict_values = set(len(v) for v in dict_p_stud_to_task.values())
    assert len(n_groups_from_dict_values)==1, "Input dict_p_stud_to_task implies varying number of groups"
    n_groups= list(n_groups_from_dict_values)[0]
    assert n_groups==len(dict_p_stud_to_task), "not enough keys"

    bip_block_probs = np.zeros((2*n_groups, 2*n_groups))
    # Fill in the probabilities within and between groups
    # Only filling probs of students to interact with tasks. 
    # Since the interactions are symmetric, the information on tasks interacting with studetns is redundant and can be obtained by summing with the transpose (see below )
    #
    # even indexes for students
    for row in range(0,2*n_groups,2):
        # odd indexes are for tasks
        for col in range(1,2*n_groups,2):
            stud_ix = row//2
            task_ix = int(col/2)
            bip_block_probs[row,col] = dict_p_stud_to_task[stud_ix][task_ix]
    return bip_block_probs + bip_block_probs.T



def sample_dcsbm(num_nodes, B, expected_degrees):
    """
    Samples a network from a degree-corrected stochastic block model
    """
    # assert False, "check that num blcks an block matrix agree"
    assert B.shape[0] == B.shape[1], "B should be square"
    num_blocks = B.shape[0]
    m = np.random.choice(num_blocks, size=num_nodes)

    # generate edges
    edge_list = []
    for i in range(num_nodes):
        for j in range(i+1, num_nodes):
            p_edge = B[m[i], m[j]]*expected_degrees[i]*expected_degrees[j]/(sum(expected_degrees))
            p_edge = min(p_edge, 1)
            assert p_edge <= 1, f"Edge probability larger than 1: {p_edge}"
            if np.random.rand() < p_edge:
                edge_list.append((i, j))

    # Create a graph and add nodes
    # network = pp.Network()
    # for u,v in edge_list:
    #     network.add_edge(u,v)
    
    # return network
    return edge_list, m

# num_nodes = 500
# # dictionary with stud index-topic as key, and list of probabiliy of interacting with task of other index-topics
# dict_p_stud_to_task = {}
# dict_p_stud_to_task[0] = [1,0,0]#,.00005]
# dict_p_stud_to_task[1] = [0,1,0]#,.001]
# dict_p_stud_to_task[2] = [0,0,1]
# bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
# # print(bip_block_probs)


# theta = np.random.randint(1,num_nodes//3,num_nodes) #np.random.uniform(low=1, high=1, size=num_nodes)  # Random 
# # theta = [int(np.random.exponential(20)) for _ in range(num_nodes)]# np.random.randint(1,100,num_nodes) #np.random.uniform(low=1, high=1, size=num_nodes)  # Random 
# edges,labels = sample_dcsbm(num_nodes, bip_block_probs, theta)

# %%
# from collections import Counter
# Counter(labels)

# %%
import torch
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from manage_experiments import *

from utils import generate_multidimensional_data_object_synthetic_geometric

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import json

# %%
# student_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==0]
# student_reindexed = {j:i for i,j in enumerate(student_indices)}
# task_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==1]
# task_reindexed = {j:i for i,j in enumerate(task_indices)}
# n_students = len(student_indices)
# n_tasks = len(task_indices)

# edge_reordered_reindexed = []
# for edge in edges:
#     if edge[0] in student_indices:
#         e = (student_reindexed[edge[0]], task_reindexed[edge[1]])
#     else:
#         e = (student_reindexed[edge[1]], task_reindexed[edge[0]])
#     edge_reordered_reindexed.append(e)

# # mapping groups to new indexing and node type separation
# student_groups = np.zeros(n_students,dtype=int)
# tasks_groups = np.zeros(n_tasks, dtype=int)

# for old_ix, new_ix in student_reindexed.items():
#     student_groups[new_ix] = labels[old_ix]

# for old_ix, new_ix in task_reindexed.items():
#     tasks_groups[new_ix] = labels[old_ix]

# # Maiking students interact with tasks according to generated topology
# p_pass_in = .9
# p_pass_out = .1
# y = []
# for s_ix, t_ix in edge_reordered_reindexed:
#     if student_groups[s_ix] == tasks_groups[t_ix]:
#         p = p_pass_in
#     else:
#         p = p_pass_out
#     y.append(np.random.binomial(1,p))

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def logarithm_base(x, base):
    return np.log(x)/np.log(base)

# %%
import torch_geometric.transforms as T

def create_data_object_SBM(edges, labels, bip_block_p_pass_probs, theta, degree_p_pass_correction=True):

    student_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==0]
    student_reindexed = {j:i for i,j in enumerate(student_indices)}
    task_indices = [j for i,j in zip(labels, range(len(labels))) if i%2==1]
    task_reindexed = {j:i for i,j in enumerate(task_indices)}
    n_students = len(student_indices)
    n_tasks = len(task_indices)

    edge_reordered_reindexed = []
    for edge in edges:
        if edge[0] in student_indices:
            e = (student_reindexed[edge[0]], task_reindexed[edge[1]])
        else:
            e = (student_reindexed[edge[1]], task_reindexed[edge[0]])
        edge_reordered_reindexed.append(e)

    # mapping groups to new indexing and node type separation
    student_groups = np.zeros(n_students,dtype=int)
    tasks_groups = np.zeros(n_tasks, dtype=int)

    for old_ix, new_ix in student_reindexed.items():
        student_groups[new_ix] = labels[old_ix]

    for old_ix, new_ix in task_reindexed.items():
        tasks_groups[new_ix] = labels[old_ix]


    # Maiking students interact with tasks according to generated topology
    # p_pass_in = .9
    # p_pass_out = .1
    y = []
    theta_m = max(theta)
    # tau = .0
    # eta = .99
    # s = - np.log((1 + eta) / eta) / theta_m
    # print(s)
    for s_ix, t_ix in edge_reordered_reindexed:
        # if student_groups[s_ix] == tasks_groups[t_ix]:
        #     p = p_pass_in
        # else:
        #     p = p_pass_out
        p_pass = bip_block_p_pass_probs[student_groups[s_ix], tasks_groups[t_ix]]
        # if degree_p_pass_correction:
        #     # correction = logarithm_base(theta[s_ix], base)/logarithm_base(theta_m, base)#tau + (1 - tau)*sigmoid(s * theta[s_ix])
        #     p_pass = p_pass * correction
        y.append(np.random.binomial(1, p_pass))
    

    data  = HeteroData()

    # Save node indices
    data['student'].node_id = torch.arange(n_students)
    data['item'].node_id = torch.arange(n_tasks)


    # Add the node features
    data['student'].x= torch.eye(n_students)
    data['item'].x = torch.eye(n_tasks)

    # Add the edge indices
    data['student', 'responds', 'item'].edge_index = torch.from_numpy(np.array(edge_reordered_reindexed).T).to(torch.long)

    #add the edge attrs
    data['student', 'responds', 'item'].edge_attr = torch.tensor([1]*len(y)).to(torch.float).reshape(-1,1)

    # Add the edge label
    data['student', 'responds', 'item'].y = torch.from_numpy(np.array(y)).to(torch.long)

    # We use T.ToUndirected() to add the reverse edges from subject to students 
    # in order to let GNN pass messages in both ways
    data = T.ToUndirected()(data)
    del data['item', 'rev_responds', 'student'].edge_attr  # Remove 'reverse' label.
    del data['item', 'rev_responds', 'student'].y  # Remove 'reverse' label.
    return data


def generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs, degree_p_pass_correction=False):
    edges, labels = sample_dcsbm(num_nodes, bip_block_probs, theta) #generate_observations_tree_of_topics(n, n_students, n_tasks, tree_depth,branching_factor,p_ER,skill_mismatch_penalty)
    data = create_data_object_SBM(edges, labels, bip_block_p_pass_probs, theta, degree_p_pass_correction)
    # print("network density",data.num_edges/(2*n_students*n_tasks))
    return data


# data_object = generate_data_object_SBM(num_nodes, bip_block_probs, theta)
# data_object

# %%
# Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


def line_plot_with_std(list_scores, parameters, fname):

    # Convert the list of lists to a Pandas DataFrame
    df = pd.DataFrame(list_scores)

    # Calculate the mean and standard deviation of each row
    mean = df.mean(axis=1)
    std = df.std(axis=1)

    # Create a figure and an axis
    fig, ax = plt.subplots()

    # Plot the mean line
    ax.plot(mean, color='blue', label='Mean')

    # Plot the shaded region around the mean line
    ax.fill_between(df.index, mean-std, mean+std, color='lightblue', alpha=0.5, label='Standard deviation')

    # Add some labels and a legend
    ax.set_xlabel('Index')
    ax.set_ylabel('Value')
    # ax.legend()

    # change x-ticks to start from 
    n_tasks_per_student_list = list(range(
        parameters['min_n_tasks_per_student'],
        parameters['max_n_tasks_per_student'],
        parameters['step_n_tasks_per_student']))
    ax.set_xticks(range(len(n_tasks_per_student_list)), n_tasks_per_student_list, rotation=45)

    # Show and save the plot
    plt.grid()
    plt.xlabel('Number of tasks per student')
    plt.ylabel('Balanced Accuracy')
    fnameplot = fname.replace('results', 'pdf')
    plt.savefig(fnameplot)
    # plt.show()

# %%
def visualise_confusion_matrix(json_content, fname):
    fig, ax = plt.subplots(ncols = 1, figsize=(8,6))
    
    plt.imshow(json_content["Confusion_2_test"], interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()

    classes = [0, 1]
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    part1, part2 = fname.split('.')
    part1 = part1 + '_consfusion_matrix'
    fname = '.'.join([part1, part2])
    fnameplot = fname.replace('results', 'pdf')
    plt.savefig(fnameplot)

# %%
from IPython.utils import io
import matplotlib.pyplot as plt

import string
def create_filename_results(parameters,fold):
    file_name = ' '.join([f"{str(key)}-{str(value)}" for key, value in parameters.items() if key not in ['bip_block_probs','theta','bip_block_p_pass_probs', 'degree_p_pass_correction', 'base']])
    file_name += ''.join(random.choice(string.ascii_letters + string.digits) for _ in range(4))
    file_name.replace(".","")
    file_name+=".results"
    return os.path.join(fold, file_name)


#n_students_per_task_list = [2**i for i in n_students_per_task_list]

import json
def synthetic_density_effect_runs(data, parameters,parameters_density, folder = 'final_results'):
    parameters = {**parameters, **parameters_density}
    scores = []
    scores_roc = []
    list_scores = []
    list_scores_roc = []
    for _ in range(parameters["n_runs"]):
        with io.capture_output() as captured:
            
            cv_out = perform_cross_validation(data, parameters, save_embeddings=True)

            score = 0
            roc = 0
            inner_list_scores = []
            inner_list_scores_roc = []
            for fold_n in range(parameters["n_splits"]):
                score += cv_out[f"Balanced Accuracy_{fold_n}_test"]
                roc += cv_out[f"AUC_{fold_n}_test"]
                inner_list_scores.extend([cv_out[f"Balanced Accuracy_{fold_n}_test"]])
                inner_list_scores_roc.extend([cv_out[f"AUC_{fold_n}_test"]])
            score = score / parameters["n_splits"]
            roc = roc / parameters["n_splits"]
            scores.append(score)
            scores_roc.append(roc)

            list_scores.append(inner_list_scores)
            list_scores_roc.append(inner_list_scores_roc)

    # density = data.num_edges/(2*parameters["n_students"]*parameters["n_tasks"]) 
    res_dict = dict(zip(list(range(parameters["n_runs"])),scores))
    res_dict_roc = dict(zip(list(range(parameters["n_runs"])),scores_roc))
    output_dict = {
        **parameters,
        # "density":density,
        "res_dict":res_dict,
        "res_dict_roc":res_dict_roc,
        "list_scores":dict(zip(list(range(parameters["n_runs"])),list_scores)),
        "list_scores_roc":dict(zip(list(range(parameters["n_runs"])),list_scores_roc)),
    }
    output_dict['bip_block_probs'] = output_dict['bip_block_probs'].tolist()
    output_dict['theta'] = output_dict['theta'].tolist()
    output_dict['bip_block_p_pass_probs'] = output_dict['bip_block_p_pass_probs'].tolist()
    fname = create_filename_results(parameters_density, folder)
    # print the types of items
    # print({i: type(output_dict[i]) for i,j in output_dict.items()})
    with open(fname,'w') as f:
        json.dump(output_dict, f, skipkeys=True)
    
    # save results
    # print(density)
    print([np.mean(s) for s in list_scores])
    # line_plot_with_std(list_scores=list_scores, parameters= parameters, fname=fname)

    # # save embeddings
    # visualise_embeddings(output_dict, fname=fname)

    # visualise_embeddings_concatenated(output_dict, data['student', 'responds', 'item'].edge_index, data['student', 'item'].y, fname = fname) # plot with indices of train-test split
    
    # # plot with indices of train-test split
    


    # visualise_confusion_matrix(cv_out, fname=fname)

# %%
parameters = {
    "hidden_dims": None,
    'model_type': None,
    "df_name": "synthetic.salamoia",
    "method": "EdgeClassifier",
    "epochs": 2000,
    "learning_rate": 0.05,
    "weight_decay": 0,
    "dropout": 0.0,
    "early_stopping": 250,
    "n_splits": 10,
    "device": "cuda:1",
    "done": False,
    "batch_size":64*4096,
    #
    }

# n_groups = 3
# # probability of connections between students and tasks
# dict_p_stud_to_task = {}
# dict_p_stud_to_task[0] = [1,1/(n_groups - 1),1/(n_groups - 1)]
# dict_p_stud_to_task[1] = [1/(n_groups - 1),1,1/(n_groups - 1)]
# dict_p_stud_to_task[2] = [1/(n_groups - 1),1/(n_groups - 1),1]
# bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
# # probability of passing a task given the student and the task
# dict_p_pass_stud_to_task = {}
# dict_p_pass_stud_to_task[0] = [.8,.1,.05]
# dict_p_pass_stud_to_task[1] = [.2,.7,.1]
# dict_p_pass_stud_to_task[2] = [.1,.3,.6]
# bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_stud_to_task)

# theta = np.random.randint(1,num_nodes//3,num_nodes)

parameters_density = {
    'n_runs': 1,
    'num_nodes':500,
    'bip_block_probs':None,
    'bip_block_p_pass_probs':None,
    'theta':None,
    'n_groups':None,
    'theta_type':None,
    'p_pass_out': None,
    'p_pass_in': None,	
    'degree_p_pass_correction': True,
}

# %%
# NB: having only the leaves might make it easier for IRT since it just creates separated bins (i.e., the leaves) and easy tasks (the ones sampled close to the root node)
#  Instead, with a GNN we want to leverage the ...ability to encode the underlying tree structure (HOW might the GNN do it, specifically?)
#  (np.random.normal(parameters_density["num_nodes"]/n_groups, std, parameters_density["num_nodes"]), "gaussian"), 
std = parameters_density["num_nodes"]/100
for correction in [False]:
    parameters_density['degree_p_pass_correction'] = correction
    for n_groups in [4]: #3,4,5
        parameters_density['n_groups'] = n_groups
        for theta in [ (np.random.randint(1,parameters_density["num_nodes"]//n_groups,parameters_density["num_nodes"]), "uniform"), (np.random.normal(parameters_density["num_nodes"]/n_groups, std, parameters_density["num_nodes"]), "gaussian")]:#, (np.random.exponential(100,parameters_density["num_nodes"]), "exponential")]:
            parameters_density['theta'] = theta[0]
            parameters_density['theta_type'] = theta[1]
            for mul_p_connection in [1]:
                parameters_density['mul_p_connection'] = mul_p_connection
                dict_p_stud_to_task = {}
                for i in range(n_groups):
                    dict_p_stud_to_task[i] = [mul_p_connection/(n_groups-1)]*n_groups
                    dict_p_stud_to_task[i][i] = 1
                bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)
                parameters_density['bip_block_probs'] = bip_block_probs
                parameters_density['p_pass_in'] = 1
                for p_pass_out in [.5, .7]: #.1, .3, .5, .7
                    dict_p_pass_stud_to_task = {}
                    for i in range(n_groups):
                        dict_p_pass_stud_to_task[i] = [p_pass_out]*n_groups
                        dict_p_pass_stud_to_task[i][i] = 1
                    parameters_density['p_pass_out'] = p_pass_out
                    bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_pass_stud_to_task)
                    parameters_density['bip_block_p_pass_probs'] = bip_block_p_pass_probs

                

                    parameters = {**parameters, **parameters_density}

                    for _ in range(50):
                        data = generate_data_object_SBM(
                                num_nodes= parameters["num_nodes"],
                                bip_block_probs = parameters["bip_block_probs"],
                                theta = parameters["theta"],
                                bip_block_p_pass_probs = parameters["bip_block_p_pass_probs"],
                                # base = parameters["base"],
                                degree_p_pass_correction=parameters["degree_p_pass_correction"]
                        )
                        
                        for model_type,hidden_dims in [
                            ("IRT",3),
                            ("GNN", [
                                16,
                                16,
                                8])]:
                            parameters["model_type"] = model_type
                            parameters["hidden_dims"] = hidden_dims
                            print('Model type:', model_type, 'hidden_dims:', hidden_dims, 'n_groups:', n_groups, 'theta:', theta[1], 'mul_p_connection:', mul_p_connection, 'p_pass_out:', p_pass_out)#, 'base:', base)
                            print('y counts', torch.bincount(data['student', 'responds', 'item'].y))
                            synthetic_density_effect_runs(data, parameters=parameters,
                                                        parameters_density=parameters_density,
                                                        )
# Out:
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1015, 2925])
# [0.5283386135834719]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1015, 2925])
# [0.5160581853826627]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1037, 2928])
# [0.5300762243879718]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1037, 2928])
# [0.5512012251861869]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1010, 2797])
# [0.5393999741900539]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1010, 2797])
# [0.5380141013552556]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1007, 2972])
# [0.519616953830837]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1007, 2972])
# [0.569639132062664]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 974, 2893])
# [0.5338239011672771]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 974, 2893])
# [0.5093231625566752]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 938, 2996])
# [0.49408863615359844]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 938, 2996])
# [0.5232645987111868]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 999, 2930])
# [0.5170993016841094]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 999, 2930])
# [0.5353889346160867]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 964, 3015])
# [0.5271994119501843]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 964, 3015])
# [0.5562180579304993]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 961, 2912])
# [0.5111820316215318]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 961, 2912])
# [0.5527274594954649]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 2957])
# [0.5269836569751816]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 2957])
# [0.5241836038452468]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 990, 2912])
# [0.5549017997037443]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 990, 2912])
# [0.5524793049923068]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 993, 2952])
# [0.5564450243954345]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 993, 2952])
# [0.528968165169428]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 979, 2899])
# [0.5519615861104752]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 979, 2899])
# [0.5313138542475435]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1003, 2853])
# [0.5507548438894727]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1003, 2853])
# [0.5223329792161819]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 981, 2896])
# [0.5046645617209655]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 981, 2896])
# [0.5205157271602711]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2862])
# [0.5343765463757486]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2862])
# [0.5211945807966973]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 978, 2942])
# [0.49918679716938535]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 978, 2942])
# [0.5491728446085775]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 949, 2975])
# [0.5450941030327932]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 949, 2975])
# [0.566355653337028]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 974, 2951])
# [0.49679697215932367]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 974, 2951])
# [0.5060528460978122]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 929, 2942])
# [0.5507909779523416]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 929, 2942])
# [0.5498500845016002]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 943, 2902])
# [0.5163867407877061]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 943, 2902])
# [0.5371757591272145]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1031, 2903])
# [0.531476817161946]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1031, 2903])
# [0.5287763279841271]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 987, 2859])
# [0.5105479053798382]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 987, 2859])
# [0.5223420796928446]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1020, 2981])
# [0.515256814133092]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1020, 2981])
# [0.5492332341595081]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 983, 2921])
# [0.5108334190461987]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 983, 2921])
# [0.5463629541550802]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1011, 2953])
# [0.5305089372118716]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1011, 2953])
# [0.5212288513347307]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 932, 2942])
# [0.5310375916185495]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 932, 2942])
# [0.5233848226091459]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1013, 2922])
# [0.525195830741711]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1013, 2922])
# [0.5375133863606588]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1008, 2909])
# [0.545943003454892]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1008, 2909])
# [0.5282042788973442]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 938, 2935])
# [0.5305362453558371]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 938, 2935])
# [0.5062898852940786]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 965, 2895])
# [0.5198311427885908]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 965, 2895])
# [0.5276775201864408]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 994, 2855])
# [0.5136833748121077]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 994, 2855])
# [0.5451056653479981]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 975, 2996])
# [0.5271048155966784]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 975, 2996])
# [0.5388734812326883]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 3000])
# [0.5424202027040532]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 3000])
# [0.5928490334052776]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 966, 2920])
# [0.5231027704703299]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 966, 2920])
# [0.5822201742269557]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2942])
# [0.5226927648664376]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2942])
# [0.5519433472915709]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2931])
# [0.5189631428045006]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2931])
# [0.5226494685131468]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 942, 2916])
# [0.5004210373593481]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 942, 2916])
# [0.5173456768803734]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 980, 2945])
# [0.5282611936565548]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 980, 2945])
# [0.49584137096895936]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2911])
# [0.5028279441930903]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 996, 2911])
# [0.5198101691020528]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 969, 2937])
# [0.5277810881386357]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 969, 2937])
# [0.555460197922943]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1020, 2946])
# [0.5287711117218763]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1020, 2946])
# [0.5366498490048066]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 997, 2875])
# [0.5052992669055724]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 997, 2875])
# [0.52158347785225]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2879])
# [0.5122352035678848]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2879])
# [0.5123423431850131]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 977, 2938])
# [0.5472664937576955]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 977, 2938])
# [0.5617777848800426]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1000, 2865])
# [0.5435892746142625]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1000, 2865])
# [0.532876941092849]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1001, 2866])
# [0.5269867682484118]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1001, 2866])
# [0.5594342843681149]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2941])
# [0.5127973448370955]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 973, 2941])
# [0.5158414801618154]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 2872])
# [0.540285272065059]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([ 988, 2872])
# [0.5330990193328422]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1012, 3009])
# [0.5322758210313402]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1012, 3009])
# [0.5381885581952293]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 598, 3227])
# [0.5186087042182567]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 598, 3227])
# [0.5133952808963425]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 554, 3316])
# [0.5037208579445577]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 554, 3316])
# [0.5010275910697775]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 584, 3391])
# [0.5177137029313128]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 584, 3391])
# [0.5014711858857449]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 569, 3311])
# [0.5302667375560665]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 569, 3311])
# [0.5144251849925072]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 575, 3274])
# [0.5168466217268968]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 575, 3274])
# [0.5044662111344207]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3292])
# [0.5014248096182442]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3292])
# [0.504364025988853]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 618, 3230])
# [0.5069320539339206]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 618, 3230])
# [0.508507596621741]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 608, 3340])
# [0.48959418640671826]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 608, 3340])
# [0.5171631659815819]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 610, 3262])
# [0.4896593130906225]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 610, 3262])
# [0.5121977059429138]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 588, 3313])
# [0.5031274924461421]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 588, 3313])
# [0.4868020262345313]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 627, 3218])
# [0.5188736728155477]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 627, 3218])
# [0.4807479637711472]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 568, 3317])
# [0.4981395375953987]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 568, 3317])
# [0.5270093448262719]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 581, 3242])
# [0.501112956028883]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 581, 3242])
# [0.504073373504846]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 615, 3283])
# [0.5019496800337586]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 615, 3283])
# [0.486552737389969]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 609, 3360])
# [0.4803874938034274]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 609, 3360])
# [0.49976825177161655]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 561, 3338])
# [0.4937676906077317]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 561, 3338])
# [0.49847762231159914]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 512, 3330])
# [0.5163952128482305]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 512, 3330])
# [0.5258568669993542]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 587, 3349])
# [0.507171411299288]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 587, 3349])
# [0.5127470112585433]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 617, 3363])
# [0.4753904557470382]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 617, 3363])
# [0.5267666134604743]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 595, 3333])
# [0.5204320450001154]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 595, 3333])
# [0.4893797497343709]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 535, 3290])
# [0.4974560747376918]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 535, 3290])
# [0.4973958979242841]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 621, 3395])
# [0.49451673954642406]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 621, 3395])
# [0.5001995300648617]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 604, 3346])
# [0.4888364219803112]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 604, 3346])
# [0.4935111209717344]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 566, 3286])
# [0.524117108315218]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 566, 3286])
# [0.5098180565032121]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 582, 3283])
# [0.5117106959529247]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 582, 3283])
# [0.5061526642225189]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 572, 3326])
# [0.48468938196348255]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 572, 3326])
# [0.5186456180884317]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3295])
# [0.5109708518760332]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3295])
# [0.5068460425580666]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 587, 3254])
# [0.5077744635105749]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 587, 3254])
# [0.5125440609157901]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 594, 3299])
# [0.518230165949699]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 594, 3299])
# [0.5133237986547237]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 596, 3323])
# [0.5037612484795713]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 596, 3323])
# [0.5274463741261625]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 581, 3302])
# [0.5228204649850138]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 581, 3302])
# [0.5028197648755428]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 531, 3453])
# [0.5268779219516058]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 531, 3453])
# [0.5140490139383109]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 584, 3334])
# [0.5071634754141143]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 584, 3334])
# [0.4999240257163309]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 599, 3385])
# [0.47943525244747287]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 599, 3385])
# [0.513687879594255]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 592, 3337])
# [0.5198570496422168]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 592, 3337])
# [0.517434620382184]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 558, 3319])
# [0.4937963191060891]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 558, 3319])
# [0.5072356241453179]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 642, 3335])
# [0.489599176631483]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 642, 3335])
# [0.4791796394316779]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 600, 3291])
# [0.5160697429730801]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 600, 3291])
# [0.5256741846849297]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 537, 3236])
# [0.49374875201731994]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 537, 3236])
# [0.49652545858790775]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 615, 3383])
# [0.5025416917512747]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 615, 3383])
# [0.5157310512681803]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 574, 3298])
# [0.5223255293487479]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 574, 3298])
# [0.5074215855433881]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 576, 3294])
# [0.5013693512815202]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 576, 3294])
# [0.5252991980516621]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3299])
# [0.4930671551642997]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 563, 3299])
# [0.507414214685095]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 575, 3273])
# [0.48368518600143967]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 575, 3273])
# [0.5005980394057846]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 548, 3257])
# [0.5004320450705197]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 548, 3257])
# [0.4939984126716488]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 600, 3251])
# [0.5312282392408287]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 600, 3251])
# [0.4845471711883004]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 641, 3284])
# [0.49708404581348364]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 641, 3284])
# [0.5036029872027885]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 585, 3259])
# [0.48085762387179704]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 585, 3259])
# [0.4758804315545331]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 573, 3370])
# [0.5167863009142873]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 573, 3370])
# [0.5119038653980732]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 586, 3308])
# [0.4827219054778463]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: uniform mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([ 586, 3308])
# [0.48177147115388974]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1891, 5838])
# [0.5982099749243407]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1891, 5838])
# [0.6533005802633554]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1982, 5784])
# [0.5940419287647769]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1982, 5784])
# [0.6470671893248514]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1966, 5845])
# [0.5895930049165949]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1966, 5845])
# [0.6450954944595138]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2014, 5833])
# [0.6116857033052387]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2014, 5833])
# [0.6593910516256096]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1977, 5970])
# [0.630889344727634]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1977, 5970])
# [0.6521722738593768]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1950, 5845])
# [0.6183656179490876]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1950, 5845])
# [0.6612395881578144]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1892, 5793])
# [0.608724259850821]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1892, 5793])
# [0.6283238248158993]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1947, 5880])
# [0.612865912793191]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1947, 5880])
# [0.6480371853708341]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1956, 5694])
# [0.57955568296457]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1956, 5694])
# [0.6560577861743649]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1990, 5919])
# [0.6071081194272703]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1990, 5919])
# [0.6435582072228451]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1959, 5801])
# [0.5755649176846537]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1959, 5801])
# [0.6310285607387318]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1953, 5910])
# [0.6108866850659586]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1953, 5910])
# [0.6562413411864713]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1893, 5868])
# [0.6212998950846556]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1893, 5868])
# [0.6798660091299391]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1934, 5794])
# [0.628213593051987]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1934, 5794])
# [0.7079170267917325]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1903, 5857])
# [0.6321049739032678]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1903, 5857])
# [0.6370468391216384]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1883, 5799])
# [0.6082827427614267]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1883, 5799])
# [0.665074402704587]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1978, 5811])
# [0.6053235593173157]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1978, 5811])
# [0.6171067122517916]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1974, 5955])
# [0.6052523109382015]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1974, 5955])
# [0.6578546048439506]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1960, 5930])
# [0.6010771703928741]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1960, 5930])
# [0.6663427531461543]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1940, 5867])
# [0.6294003330388661]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1940, 5867])
# [0.6889166197607868]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1919, 5839])
# [0.61199180656117]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1919, 5839])
# [0.6637153807922015]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1947, 5995])
# [0.5861204728372066]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1947, 5995])
# [0.6430652614877757]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2029, 6008])
# [0.6186043978746827]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2029, 6008])
# [0.6889706122115922]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1982, 5954])
# [0.5979505868706022]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1982, 5954])
# [0.6316185619518719]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2045, 5859])
# [0.613646957128066]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2045, 5859])
# [0.6766766960273058]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1928, 5885])
# [0.6126187022265004]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1928, 5885])
# [0.7049649788078175]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1911, 5872])
# [0.5891801350701906]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1911, 5872])
# [0.6174347055386764]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1981, 5909])
# [0.610532189395129]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1981, 5909])
# [0.6787775839772212]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1914, 5967])
# [0.6154398814179249]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1914, 5967])
# [0.6729306639818289]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1903, 5969])
# [0.6327849223209945]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1903, 5969])
# [0.6858020846911308]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1936, 5799])
# [0.5943928594555579]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1936, 5799])
# [0.6741440760339955]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1917, 5929])
# [0.614782385033634]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1917, 5929])
# [0.627602106002]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1865, 5845])
# [0.6039672216254905]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1865, 5845])
# [0.6623964609036583]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1904, 5813])
# [0.5996045321805219]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1904, 5813])
# [0.6732353734283827]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1980, 5921])
# [0.5902144846082304]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1980, 5921])
# [0.6590550400454469]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1934, 5818])
# [0.6247777093880266]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1934, 5818])
# [0.6253504878606548]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1922, 5952])
# [0.5933364706787531]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1922, 5952])
# [0.69480078291281]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2066, 5994])
# [0.6027785554216099]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2066, 5994])
# [0.6918000884183176]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1961, 5936])
# [0.5919179619908348]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1961, 5936])
# [0.6297872457456297]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1972, 5870])
# [0.6264720766138556]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1972, 5870])
# [0.6530183143107224]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1933, 5812])
# [0.6079127863748781]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1933, 5812])
# [0.6456380085975237]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1964, 6009])
# [0.5994508921227212]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1964, 6009])
# [0.6967358036953668]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1993, 5789])
# [0.6312737019599816]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1993, 5789])
# [0.6789460936875965]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1918, 5864])
# [0.615504669017412]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1918, 5864])
# [0.673332568275124]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2007, 5815])
# [0.631388087528905]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([2007, 5815])
# [0.6874297167542636]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1859, 5896])
# [0.6057297250515107]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1859, 5896])
# [0.6521492413030436]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1885, 5797])
# [0.5800400050967485]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1885, 5797])
# [0.6322582950354452]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1977, 5834])
# [0.6115784772015207]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1977, 5834])
# [0.6820553560931443]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1899, 5846])
# [0.5807152581265047]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1899, 5846])
# [0.6477889087237688]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1913, 5942])
# [0.6075018066432912]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.5
# y counts tensor([1913, 5942])
# [0.6714184475905057]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1184, 6566])
# [0.5069458140861143]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1184, 6566])
# [0.5073030880397329]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1136, 6741])
# [0.519040574596848]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1136, 6741])
# [0.5188501400040348]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1191, 6525])
# [0.48804949996176933]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1191, 6525])
# [0.48628615693217403]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1127, 6652])
# [0.4869372352046105]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1127, 6652])
# [0.5002136829316857]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1137, 6610])
# [0.535725544926797]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1137, 6610])
# [0.5013601823717222]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1174, 6602])
# [0.501194586982358]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1174, 6602])
# [0.5261677876340192]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1155, 6687])
# [0.5441513159535862]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1155, 6687])
# [0.5291601608708896]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1205, 6542])
# [0.5196035507863445]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1205, 6542])
# [0.5177678412395292]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1193, 6509])
# [0.5034147165873889]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1193, 6509])
# [0.4990539838548269]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1141, 6600])
# [0.5267371234981074]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1141, 6600])
# [0.5364662885978773]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1079, 6713])
# [0.4895887167448798]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1079, 6713])
# [0.5017181280201003]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1229, 6505])
# [0.5055971196284601]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1229, 6505])
# [0.5495775213974973]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1192, 6721])
# [0.48682313707188013]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1192, 6721])
# [0.4958424018244042]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1176, 6537])
# [0.520408672202145]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1176, 6537])
# [0.4970526938940353]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1183, 6776])
# [0.5293216951397823]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1183, 6776])
# [0.5195504619372489]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1153, 6787])
# [0.5360655977303275]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1153, 6787])
# [0.5298650403844828]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1097, 6576])
# [0.5122279421992262]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1097, 6576])
# [0.509544995010131]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1219, 6809])
# [0.5043800378887455]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1219, 6809])
# [0.5039131694857727]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1137, 6731])
# [0.4899196125116186]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1137, 6731])
# [0.5128332047614759]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6669])
# [0.5137932070896831]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6669])
# [0.5140695971594091]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1139, 6841])
# [0.5272162988455895]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1139, 6841])
# [0.5300851068699544]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1197, 6642])
# [0.5163104814176773]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1197, 6642])
# [0.5359332375081373]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1203, 6631])
# [0.5151011668471672]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1203, 6631])
# [0.5046219824299962]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1192, 6645])
# [0.527133633705392]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1192, 6645])
# [0.5136157182862983]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6576])
# [0.5248582066065945]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6576])
# [0.553273643370799]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1145, 6766])
# [0.5235364593778739]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1145, 6766])
# [0.5414582842931377]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1164, 6771])
# [0.5175593324298682]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1164, 6771])
# [0.5208133612121527]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1147, 6644])
# [0.50542007008084]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1147, 6644])
# [0.5143824020264394]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1068, 6665])
# [0.5166393513921727]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1068, 6665])
# [0.5145252048053439]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1160, 6600])
# [0.5188813866203253]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1160, 6600])
# [0.5102005624123065]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1228, 6603])
# [0.5015343017077106]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1228, 6603])
# [0.5065287107411203]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1087, 6642])
# [0.5115056969518893]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1087, 6642])
# [0.5130270118055518]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1174, 6584])
# [0.5285182557817996]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1174, 6584])
# [0.5601210096485374]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1176, 6723])
# [0.509185182280636]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1176, 6723])
# [0.5074822842905186]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1202, 6674])
# [0.5313827046713776]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1202, 6674])
# [0.5314092956589294]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6608])
# [0.4981026828413827]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1186, 6608])
# [0.5238432694267618]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1138, 6678])
# [0.505515870285128]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1138, 6678])
# [0.5147659582774977]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1218, 6679])
# [0.5142629728821222]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1218, 6679])
# [0.5303163933001789]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1148, 6645])
# [0.5098318349473356]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1148, 6645])
# [0.5163280419987859]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1197, 6631])
# [0.49727862493509356]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1197, 6631])
# [0.5252147859697708]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1157, 6582])
# [0.5157645892867297]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1157, 6582])
# [0.5312122225825917]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1175, 6748])
# [0.5037927020797874]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1175, 6748])
# [0.5001059334276075]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1200, 6750])
# [0.5090997331359306]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1200, 6750])
# [0.5349863126758874]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1118, 6499])
# [0.49854963212986936]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1118, 6499])
# [0.5080104638015791]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1157, 6662])
# [0.5221165892017662]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1157, 6662])
# [0.5406139192904803]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1179, 6597])
# [0.5162911702550586]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1179, 6597])
# [0.5133499664740514]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1173, 6600])
# [0.527722871795288]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1173, 6600])
# [0.5455288977648235]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1180, 6844])
# [0.5207329991145885]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1180, 6844])
# [0.5095907056654105]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1180, 6790])
# [0.519182446558704]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1180, 6790])
# [0.5320946196620107]
# Model type: IRT hidden_dims: 3 n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1124, 6722])
# [0.5181611180331831]
# Model type: GNN hidden_dims: [16, 16, 8] n_groups: 4 theta: gaussian mul_p_connection: 1 p_pass_out: 0.7
# y counts tensor([1124, 6722])
# [0.5278898237841051]

# %%
import os
import pandas as pd
import json
import numpy as np

def read_json_files(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".results"):
            filepath = os.path.join(directory, filename)
            with open(filepath, 'r') as file:
                json_data = json.load(file)
                data.append(json_data)
    df = pd.DataFrame(data)
    return df

# %%
df = read_json_files('final_results')

# %%
# df['list_scores_latex'] = df['list_scores'].apply(lambda x: f"{np.mean([np.mean(v)*100 for v in x.values()]):.2f} ± {np.std([np.mean(v)*100 for v in x.values()]):.2f}")
df['list_scores_latex'] = df['list_scores'].apply(lambda x: f"{np.mean([v for v in x.values()])*100:.2f} ± {np.std([v for v in x.values()])*100:.2f}")

# %%
group_cols = [
    'p_pass_out', 
    # 'bip_block_p_pass_probs', 
    'theta_type', 
    'n_groups', 
    'mul_p_connection',
    'model_type',
    'degree_p_pass_correction',
    # 'base'
    ]

# %%
grouped = df.groupby(group_cols).agg({
    'list_scores': lambda x: x.apply(lambda y: np.mean([v for v in y.values()])),
    }).reset_index()

# %%
std_list = []
mean_list = []
for dict_values in df.list_scores.values:
    std_list.append(np.std(dict_values['0']))
    mean_list.append(np.mean(dict_values['0']))

df['std'] = std_list
df['mean'] = mean_list

# %%
def col_selector(df, cols, values):
    mask = np.full(len(df), True)
    for col, value in zip(cols, values):
        mask = mask & (df[col] == value)
    return mask

# %%
grouped['Mean'] = grouped['list_scores'].apply(lambda x: round(np.mean(x),2))
grouped['Std'] = grouped['list_scores'].apply(lambda x: round(np.std(x),2))

# %%
# df_list = []
# for group, df_group in grouped.groupby(['n_groups', 'theta_type', 'mul_p_connection', 'p_pass_out']):
#     try:
#         gain = (df_group[df_group['model_type'] == 'GNN']['Mean'].values[0] - df_group[df_group['model_type'] == 'IRT']['Mean'].values[0]) / df_group[df_group['model_type'] == 'IRT']['Mean'].values[0]*100
#         std = np.sqrt((df_group[df_group['model_type'] == 'GNN']['Std'].values[0])**2 + (df_group[df_group['model_type'] == 'IRT']['Std'].values[0])**2)
#         df_list.append(pd.DataFrame({
#             'n_groups': [group[0]],
#             'theta_type': [group[1]],
#             'mul_p_connection': [group[2]],
#             'p_pass_out': [group[3]],
#             'gain': [gain],
#             'std': [std]	
#         }))
#     except:
#         continue

df_list = []
for group, df_group in df.groupby(['n_groups', 'theta_type', 'mul_p_connection', 'p_pass_out', 'degree_p_pass_correction']):
    try:
        gain = (df_group[df_group['model_type'] == 'GNN']['mean'].values[0] - df_group[df_group['model_type'] == 'IRT']['mean'].values[0]) / df_group[df_group['model_type'] == 'IRT']['mean'].values[0]*100
        std = np.sqrt((df_group[df_group['model_type'] == 'GNN']['std'].values[0])**2 + (df_group[df_group['model_type'] == 'IRT']['std'].values[0])**2)
        df_list.append(pd.DataFrame({
            'n_groups': [group[0]],
            'theta_type': [group[1]],
            'mul_p_connection': [group[2]],
            'p_pass_out': [group[3]],
            # 'base': [group[4]],
            'degree_p_pass_correction': [group[4]],
            'gain': [gain],
            'std': [std *100],
            'bottom': df_group[df_group['model_type'] == 'IRT']['mean'].values[0]*100	
        }))
    except:
        continue

# %%
new_df = pd.concat(df_list)

# %%
mul_p_connection = 1


theta_types = ['gaussian', 'uniform']
n_groups = [3, 4, 5]
base = 10
degree_p_pass_correction = True

fig, axes = plt.subplots(
    len(n_groups),
    len(theta_types),
    figsize=(5, 7),
    sharey=True
    )
for theta_type in theta_types: 
    for ng in n_groups:
        col = theta_types.index(theta_type)
        row = n_groups.index(ng)
        sub_new_df = new_df[
            (new_df['theta_type'] == theta_type) & 
            (new_df['n_groups'] == ng) & 
            (new_df['mul_p_connection'] == mul_p_connection) 
            # (new_df['base'] == base) &
            # (new_df['degree_p_pass_correction'] == degree_p_pass_correction)
            ]
        
        
        axes[row,col].grid()
        # sns.barplot(data=sub_new_df, x='p_pass_out', y='gain', ax = axes[row,col])
        # axes[row,col].set_title(f" {theta_type}, {ng} groups")
        # color the bars: redu if positive gain, blue if negative
        sub_new_df = sub_new_df.copy()
        sub_new_df['color'] = sub_new_df['gain'].apply(lambda x: 'blue' if x>0 else 'red')
        axes[row, col].bar(
            x=sub_new_df['p_pass_out'],
            height=sub_new_df['gain'],
            yerr=sub_new_df['std'],
            color=sub_new_df['color'].values.tolist(),
            width=0.1,
            align='center',
            bottom=sub_new_df['bottom'],
            zorder = 2,
            capsize=2
            )
        axes[row,col].set_title(f"{theta_type.capitalize()}, $g=$ {ng}")# {base} base")
        # axes[row,col].set_xlabel('p_pass_out')
        if col == 0:
            axes[row,col].set_ylabel('Gain (%)')

        if row == len(n_groups) - 1:
            axes[row,col].set_xlabel('$p_{out}$')

        axes[row,col].set_xticks(sub_new_df['p_pass_out'])
        axes[row,col].set_yticks(np.arange(40, 100, 10))

        # axes[row,col].set_ylim(-20, 20)

# theta_type = 'uniform'
# n_groups = 3

# sub_new_df = new_df[(new_df['theta_type'] == theta_type) & (new_df['n_groups'] == n_groups) & (new_df['mul_p_connection'] == mul_p_connection)]


# fig, axes = plt.subplots(1, 1, figsize=(10, 15))


# sns.barplot(data=sub_new_df, x='p_pass_out', y='gain', ax = axes)
# axes.set_title("fucl")
plt.tight_layout()
plt.savefig(f'plots_synthetic/Mul_p_connection_{mul_p_connection}.pdf')

# %%
df[(df['model_type'] == 'GNN') & (df['mul_p_connection'] == 2/3) & (df['p_pass_out'] == 0.1) & (df['theta_type'] == 'lognormal') & (df['n_groups'] == 3)]

# %%
df[(df['model_type'] == 'IRT') & (df['mul_p_connection'] == 2/3) & (df['p_pass_out'] == 0.1) & (df['theta_type'] == 'lognormal') & (df['n_groups'] == 3)]

# %%
new_df_gaussian = new_df[new_df['theta_type'] == 'gaussian']
new_df_lognormal = new_df[new_df['theta_type'] == 'lognormal']
new_df_uniform = new_df[new_df['theta_type'] == 'uniform']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(10, 15))

sns.barplot(x='n_groups', y='gain', data=new_df_gaussian, ax=axes[0,0])
axes[0,0].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_gaussian, ax=axes[1,0])
axes[1,0].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_gaussian, ax=axes[2,0])
axes[2,0].set_title('p_pass_out')


sns.barplot(x='n_groups', y='gain', data=new_df_uniform, ax=axes[0,1])
axes[0,1].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_uniform, ax=axes[1,1])
axes[1,1].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_uniform, ax=axes[2,1])
axes[2,1].set_title('p_pass_out')


sns.barplot(x='n_groups', y='gain', data=new_df_lognormal, ax=axes[0,2])
axes[0,2].set_title('n_groups')

sns.barplot(x='mul_p_connection', y='gain', data=new_df_lognormal, ax=axes[1,2])
axes[1,2].set_title('mul_p_connection')

sns.barplot(x='p_pass_out', y='gain', data=new_df_lognormal, ax=axes[2,2])
axes[2,2].set_title('p_pass_out')

plt.tight_layout()
plt.show()

# %%
n_nodes=500
mu = 20
plt.hist(np.random.lognormal(mean=np.log(mu),sigma=np.log(2),size=n_nodes), bins = 100)
plt.vlines(x=mu,ymin=0,ymax=15,colors="red")
plt.show()

# %%
def generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs):
    edges, labels = sample_dcsbm(num_nodes, bip_block_probs, theta) #generate_observations_tree_of_topics(n, n_students, n_tasks, tree_depth,branching_factor,p_ER,skill_mismatch_penalty)
    data = create_data_object_SBM(edges, labels, bip_block_p_pass_probs)
    # print("network density",data.num_edges/(2*n_students*n_tasks))
    return data

# %%
num_nodes = 500
theta = np.random.lognormal(mean=np.log(20),sigma=np.log(2),size=num_nodes)
n_groups = 3
mul_p_connection = 1/2
dict_p_stud_to_task = {}
for i in range(n_groups):
    dict_p_stud_to_task[i] = [mul_p_connection/(n_groups-1)]*n_groups
    dict_p_stud_to_task[i][i] = 1
bip_block_probs = generate_bipartite_block_probs(dict_p_stud_to_task)

p_pass_out = .1
dict_p_pass_stud_to_task = {}
for i in range(n_groups):
    dict_p_pass_stud_to_task[i] = [p_pass_out]*n_groups
    dict_p_pass_stud_to_task[i][i] = 1
parameters_density['p_pass_out'] = p_pass_out
bip_block_p_pass_probs = generate_bipartite_block_probs(dict_p_pass_stud_to_task)

data = generate_data_object_SBM(num_nodes, bip_block_probs, theta, bip_block_p_pass_probs)

# %%
grouped.reset_index(inplace=True)

# %%
df.columns

# %%
for p_val in grouped.p_pass_out.unique():
    print(p_val,grouped[grouped.p_pass_out == p_val].n_groups.unique())

# %%
for p_val in grouped.p_pass_out.unique():
    print(grouped[grouped.p_pass_out == p_val].mul_p_connection.unique())

# %%
grouped[grouped.p_pass_out == p_val]

# %%
import numpy as np

# %%
def sigmoid(x, alpha):
    return 1/(1+np.exp(-x/alpha))

# %%
x = np.arange(-9,10)
plt.plot(x, [sigmoid(xi,0) for xi in x], label="alpha = 0")
plt.plot(x, [sigmoid(xi,1) for xi in x], label="alpha = 1")
plt.plot(x, [sigmoid(xi,2) for xi in x], label="alpha = 2")
plt.plot(x, [sigmoid(xi,3) for xi in x], label="alpha = 3")
plt.legend()

# %%
import pathpy as pp
from collections import defaultdict 
import copy
# tree
root = "*"
max_depth = 3
nodes_at_layer = defaultdict(list)
nodes_at_layer[0].append(root)
start_nodes = ["0","1"]
nodes_at_layer[1].extend(start_nodes)
for depth in range(2,max_depth+1):
    # nodes_this_layer = []
    # nodes_prev_layer = copy.deepcopy(nodes_at_layer[depth-1])
    for node in nodes_at_layer[depth-1]:
        for base_node in start_nodes:
            nodes_at_layer[depth].append(node+base_node)


nodes_at_layer

# %%
n = pp.Network(directed = True)
for depth in range(max(nodes_at_layer)):
    if depth == 0:
        for node in nodes_at_layer[1]:
            n.add_edge(root,node)
    else:
        for node_parent in nodes_at_layer[depth]:
            for node_child in nodes_at_layer[depth+1]:
                if node_child[:-1]==node_parent:
                    n.add_edge(node_parent,node_child)
print(n.ncount())
pp.visualisation.plot(n, width = 800,height = 800)

# %%
nodes = list(n.nodes)
n_items = 100
# NB: randomly sampling nodes will disproportionately give leaves, i.e., difficult items.
item_positions = np.random.choice(nodes,size=n_items)
dict_item_positions = dict(zip(range(n_items),item_positions))

# %%
def assign_skills(n, study_hours,root="*"):
    # gives skills to students
    # we start by taking one random path from root to leaf for each student
    # extensions goes in the direction of using personalized pagerank from the root node and would include: 
    #   study hours (similar to ability, encodes number of transitions taken by the students rw)
    #   restart probability tau at any node
    #   once an end node is reached, student restards from prev visited node (or root) with prob 1
    #
    # for now just enough to reach one leaf
    T = n.transition_matrix().todense().T
    root_index = n.node_to_name_map()[root]
    ix_to_node = {v:k for k,v in n.node_to_name_map().items()}
    last_node_ix = root_index
    for _ in range(study_hours):
        last_node_ix = np.random.choice(range(n.ncount()),p=T[last_node_ix,:].tolist()[0])
    return ix_to_node[last_node_ix]


n_students = 100
dict_students_abilities = {stud_id:[] for stud_id in range(n_students)}
for stud_id in dict_students_abilities:
    # append, but potentially extend cause students can get skills in different branches
    dict_students_abilities[stud_id].append(assign_skills(n,depth+1))
# dict_students_abilities

# %%
# students interact randomly with items (erdos renyi). Student pass items if they have traversed the topic/tree-node in their learning path
p_ER = .3
edges = []
labels = []
for stud_id in dict_students_abilities:
    for item_id in dict_item_positions:
        if np.random.rand()<p_ER:
            edges.append((stud_id,item_id))
            # deciding if item is passed
            # could be made more nuanced checking how much of the path to the item_topic has been traversed by the student
            item_topic = dict_item_positions[item_id] 
            student_skills = dict_students_abilities[stud_id]
            if any([item_topic==skill[:len(item_topic)] for skill in student_skills if len(skill)>=len(item_topic)]):
                labels.append(1)
            else:
                labels.append(0)

print(sum(labels)/len(labels))

# %%
# GENERATING NODE POSITIONS AND PLOTTING THEM 
# NB: ALSO SETTING RADIUS USED BELOW

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
dimension = 2
n_students = 270
n_items = 750
#
student_geom = np.random.rand(n_students,dimension)
student_ids = range(n_students)
items_geom = np.random.rand(n_items,dimension)
items_id = range(n_students, n_students+n_items)
#
radius = .1
fig,ax = plt.subplots()
ax.scatter(student_geom[:,0],student_geom[:,1], label = "student")
ax.scatter(items_geom[:,0],items_geom[:,1], label = "item")
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
circle = Circle([.5,.5], radius, fill=False, edgecolor='red')
ax.add_patch(circle)
plt.legend()

# %%
# GENERATING NODE POSITIONS AND PLOTTING THEM 
# NB: ALSO SETTING RADIUS USED BELOW

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
dimension = 2
n_students = 270
n_items = 750
#
student_geom = np.random.rand(n_students,dimension)
student_ids = range(n_students)
items_geom = np.random.rand(n_items,dimension)
items_id = range(n_students, n_students+n_items)
#
radius = .1
fig,ax = plt.subplots()
ax.scatter(student_geom[:,0],[0]*len(student_geom[:,1]), label = "student")
ax.scatter([0]*len(items_geom[:,0]),items_geom[:,1], label = "item")
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
# circle = Circle([.5,.5], radius, fill=False, edgecolor='red')
# ax.add_patch(circle)
plt.legend()

# %%
np.random.rand()

# %%
n_students = 100
n_items = 150

list_a = [np.random.randint(50)/50 for _ in range(n_students)]
list_i = [np.random.randint(50)/50 for _ in range(n_items)]

edges = []
for i in range(n_students):
    # ability student i
    a_i = list_a[i]
    for j in range(n_items):
        # difficulty item j
        d_j = list_i[j]
        # delta gives how appropriate taks diff is for student ability
        delta = abs(a_i - d_j)
        # probability of interaction prop to inverse of delta: 
        p_i_j = 1/(2+delta)**4
        assert p_i_j <= 1
        if np.random.rand()<p_i_j:
            edges.append((i,i+j))

# %%
import pathpy as pp
n = pp.Network(directed=True)
for (u,v) in edges:
    n.add_edge(u,v)
pp.visualisation.plot(n, width =800,height = 800)

# %%
# OBTAINING PROBABILITY (AND PLOTTING PATTERNS FOR ON EDGES -- POSITION TAKING AVERAGE BETWEEN NODES INVOLVED IN THE INTERACTIONS)
label_probs = []
list_edge_points = []
for i in range(n_students):
    for j in range(n_items):
        if np.linalg.norm(student_geom[i]-items_geom[j]) < radius:
            # first coordinate used as student ability 
            # second coordinate used as item difficulty
            x = student_geom[i][0]-items_geom[j][1]
            label_probs.append(1/(1+np.exp(-x)))
            list_edge_points.append((student_geom[i]+items_geom[j])/2)

list_edge_points = np.array(list_edge_points)
plt.xlabel("Student ability")
plt.ylabel("Item diffuculty")
plt.scatter(list_edge_points[:,0],list_edge_points[:,1], c=label_probs)
plt.colorbar()

# %%
# # CREATING LIST OF EDGES
# # import pathpy as pp
# import numpy as np
# n = pp.Network()
# edges = []
# for i in range(n_students):
#     for j in range(n_items):
#         if np.linalg.norm(student_geom[i]-items_geom[j]) < radius:
#             edges.append((i,i+j))
#             n.add_edge(i,n_students+j)


# # COOL DRAGON-LIKE VISUALIZATION
# # pp.visualisation.plot(n, width =800,height = 800)
